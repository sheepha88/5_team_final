# %%
import pandas as pd
import numpy as np

# %%
pop_2020 = pd.read_csv('../finalproject/KOSIS/pop_2020.csv', encoding='euc-kr')
pop_2020 = pop_2020.rename(columns=pop_2020.iloc[0])
pop_2020 = pop_2020.drop(pop_2020.index[0])

# %%
pop_2020['jur_stn'] = ['서울용산경찰서', '서울성동경찰서', '서울광진경찰서',
                       '서울동대문경찰서','서울중랑경찰서','서울강북경찰서','서울도봉경찰서',
                       '서울노원경찰서','서울서대문경찰서','서울마포경찰서','서울양천경찰서',
                       '서울강서경찰서','서울구로경찰서','서울금천경찰서','서울영등포경찰서',
                       '서울동작경찰서','서울관악경찰서','서울송파경찰서','서울강동경찰서']
pop_2020 = pop_2020.iloc[:,[1,2]]

# %%
## 하나의 구에 두개의 관할서가 있는 경우

## 강남구
## 수서경찰서
pop_seoul_suseo = pd.read_csv('../finalproject/KOSIS/seoul/suseo_20.csv', encoding='cp949')
pop_seoul_suseo =pop_seoul_suseo.rename(columns=pop_seoul_suseo.iloc[0])
pop_seoul_suseo = pop_seoul_suseo.drop(pop_seoul_suseo.index[0])
pop_seoul_suseo = pop_seoul_suseo[pop_seoul_suseo['5세별']=='계']
pop_seoul_suseo = pop_seoul_suseo.iloc[:,2].astype(int).sum()

## 강남경찰서
pop_seoul_gangnam = pd.read_csv('../finalproject/KOSIS/seoul/gangnam_20.csv', encoding='cp949')
pop_seoul_gangnam = pop_seoul_gangnam.rename(columns=pop_seoul_gangnam.iloc[0])
pop_seoul_gangnam = pop_seoul_gangnam.drop(pop_seoul_gangnam.index[0])
pop_seoul_gangnam = pop_seoul_gangnam[pop_seoul_gangnam['5세별']=='계']
pop_seoul_gangnam = pop_seoul_gangnam.iloc[:,2].astype(int).sum()

## 종로구
## 종로경찰서
pop_seoul_jongro = pd.read_csv('../finalproject/KOSIS/seoul/jongro_20.csv', encoding='cp949')
pop_seoul_jongro = pop_seoul_jongro.rename(columns=pop_seoul_jongro.iloc[0])
pop_seoul_jongro = pop_seoul_jongro.drop(pop_seoul_jongro.index[0])
pop_seoul_jongro = pop_seoul_jongro[pop_seoul_jongro['5세별']=='계']
pop_seoul_jongro = pop_seoul_jongro.iloc[:,2].astype(int).sum()

## 혜화경찰서
pop_seoul_hyehwa = pd.read_csv('../finalproject/KOSIS/seoul/hyehwa_20.csv', encoding='cp949')
pop_seoul_hyehwa = pop_seoul_hyehwa.rename(columns=pop_seoul_hyehwa.iloc[0])
pop_seoul_hyehwa = pop_seoul_hyehwa.drop(pop_seoul_hyehwa.index[0])
pop_seoul_hyehwa = pop_seoul_hyehwa[pop_seoul_hyehwa['5세별']=='계']
pop_seoul_hyehwa = pop_seoul_hyehwa.iloc[:,2].astype(int).sum()

## 중구
## 남대문경찰서
pop_seoul_namdaemun = pd.read_csv('../finalproject/KOSIS/seoul/namdaemun_20.csv', encoding='cp949')
pop_seoul_namdaemun = pop_seoul_namdaemun.rename(columns=pop_seoul_namdaemun.iloc[0])
pop_seoul_namdaemun = pop_seoul_namdaemun.drop(pop_seoul_namdaemun.index[0])
pop_seoul_namdaemun = pop_seoul_namdaemun[pop_seoul_namdaemun['5세별']=='계']
pop_seoul_namdaemun = pop_seoul_namdaemun.iloc[:,2].astype(int).sum()

## 중부경찰서
pop_seoul_jungbu = pd.read_csv('../finalproject/KOSIS/seoul/jungbu_20.csv', encoding='cp949')
pop_seoul_jungbu = pop_seoul_jungbu.rename(columns=pop_seoul_jungbu.iloc[0])
pop_seoul_jungbu = pop_seoul_jungbu.drop(pop_seoul_jungbu.index[0])
pop_seoul_jungbu = pop_seoul_jungbu[pop_seoul_jungbu['5세별']=='계']
pop_seoul_jungbu = pop_seoul_jungbu.iloc[:,2].astype(int).sum()

## 서초구
## 방배경찰서
pop_seoul_bangbae = pd.read_csv('../finalproject/KOSIS/seoul/bangbae_20.csv', encoding='cp949')
pop_seoul_bangbae = pop_seoul_bangbae.rename(columns=pop_seoul_bangbae.iloc[0])
pop_seoul_bangbae = pop_seoul_bangbae.drop(pop_seoul_bangbae.index[0])
pop_seoul_bangbae = pop_seoul_bangbae[pop_seoul_bangbae['5세별']=='계']
pop_seoul_bangbae = pop_seoul_bangbae.iloc[:,2].astype(int).sum()


## 서초경찰서
pop_seoul_seocho = pd.read_csv('../finalproject/KOSIS/seoul/seocho_20.csv', encoding='cp949')
pop_seoul_seocho = pop_seoul_seocho.rename(columns=pop_seoul_seocho.iloc[0])
pop_seoul_seocho = pop_seoul_seocho.drop(pop_seoul_seocho.index[0])
pop_seoul_seocho = pop_seoul_seocho[pop_seoul_seocho['5세별']=='계']
pop_seoul_seocho = pop_seoul_seocho.iloc[:,2].astype(int).sum()


## 은평구
## 서부경찰서
pop_seoul_seobu = pd.read_csv('../finalproject/KOSIS/seoul/seobu_20.csv', encoding='cp949')
pop_seoul_seobu = pop_seoul_seobu.rename(columns=pop_seoul_seobu.iloc[0])
pop_seoul_seobu = pop_seoul_seobu.drop(pop_seoul_seobu.index[0])
pop_seoul_seobu = pop_seoul_seobu[pop_seoul_seobu['5세별']=='계']
pop_seoul_seobu = pop_seoul_seobu.iloc[:,2].astype(int).sum()


## 은평경찰서
pop_seoul_eunpyeong = pd.read_csv('../finalproject/KOSIS/seoul/eunpyeong_20.csv', encoding='cp949')
pop_seoul_eunpyeong = pop_seoul_eunpyeong.rename(columns=pop_seoul_eunpyeong.iloc[0])
pop_seoul_eunpyeong = pop_seoul_eunpyeong.drop(pop_seoul_eunpyeong.index[0])
pop_seoul_eunpyeong = pop_seoul_eunpyeong[pop_seoul_eunpyeong['5세별']=='계']
pop_seoul_eunpyeong = pop_seoul_eunpyeong.iloc[:,2].astype(int).sum()


## 성북구
## 성북경찰서
pop_seoul_sungbuk = pd.read_csv('../finalproject/KOSIS/seoul/sungbuk_20.csv', encoding='cp949')
pop_seoul_sungbuk = pop_seoul_sungbuk.rename(columns=pop_seoul_sungbuk.iloc[0])
pop_seoul_sungbuk = pop_seoul_sungbuk.drop(pop_seoul_sungbuk.index[0])
pop_seoul_sungbuk = pop_seoul_sungbuk[pop_seoul_sungbuk['5세별']=='계']
pop_seoul_sungbuk = pop_seoul_sungbuk.iloc[:,2].astype(int).sum()


## 종암경찰서
pop_seoul_jongam = pd.read_csv('../finalproject/KOSIS/seoul/jongam_20.csv', encoding='cp949')
pop_seoul_jongam = pop_seoul_jongam.rename(columns=pop_seoul_jongam.iloc[0])
pop_seoul_jongam = pop_seoul_jongam.drop(pop_seoul_jongam.index[0])
pop_seoul_jongam = pop_seoul_jongam[pop_seoul_jongam['5세별']=='계']
pop_seoul_jongam = pop_seoul_jongam.iloc[:,2].astype(int).sum()

# %%
twopop = pd.DataFrame({'jur_stn':['서울수서경찰서','서울강남경찰서','서울종로경찰서','서울혜화경찰서'
                                  ,'서울남대문경찰서','서울중부경찰서','서울방배경찰서','서울서초경찰서',
                                  '서울서부경찰서','서울은평경찰서','서울성북경찰서','서울종암경찰서'],
             '총인구수 (명)':[pop_seoul_suseo,pop_seoul_gangnam,pop_seoul_jongro,pop_seoul_hyehwa,
                        pop_seoul_namdaemun,pop_seoul_jungbu,pop_seoul_bangbae,pop_seoul_seocho,
                        pop_seoul_seobu,pop_seoul_eunpyeong,pop_seoul_sungbuk,pop_seoul_jongam]})

# %%
## 그외 시 분류

## 세종
sejong = 355831

## 수원
## 수원중부경찰서
pop_suwon_jungbu20 = pd.read_csv('../finalproject/KOSIS/suwon/suwon_jungbu_20.csv', encoding='cp949')
pop_suwon_jungbu20 = pop_suwon_jungbu20.rename(columns=pop_suwon_jungbu20.iloc[0])
pop_suwon_jungbu20 = pop_suwon_jungbu20.drop(pop_suwon_jungbu20.index[0])
pop_suwon_jungbu20 = pop_suwon_jungbu20[pop_suwon_jungbu20['5세별']=='계']
pop_suwon_jungbu20 = pop_suwon_jungbu20.iloc[:,2].astype(int).sum()


## 수원남부경찰서
pop_suwon_nambu20 = pd.read_csv('../finalproject/KOSIS/suwon/suwon_nambu_20.csv', encoding='cp949')
pop_suwon_nambu20 = pop_suwon_nambu20.rename(columns=pop_suwon_nambu20.iloc[0])
pop_suwon_nambu20 = pop_suwon_nambu20.drop(pop_suwon_nambu20.index[0])
pop_suwon_nambu20 = pop_suwon_nambu20[pop_suwon_nambu20['5세별']=='계']
pop_suwon_nambu20 = pop_suwon_nambu20.iloc[:,2].astype(int).sum()



## 수원서부경찰서
pop_suwon_seobu20 = pd.read_csv('../finalproject/KOSIS/suwon/suwon_seobu_20.csv', encoding='cp949')
pop_suwon_seobu20 = pop_suwon_seobu20.rename(columns=pop_suwon_seobu20.iloc[0])
pop_suwon_seobu20 = pop_suwon_seobu20.drop(pop_suwon_seobu20.index[0])
pop_suwon_seobu20 = pop_suwon_seobu20[pop_suwon_seobu20['5세별']=='계']
pop_suwon_seobu20 = pop_suwon_seobu20.iloc[:,2].astype(int).sum()



## 마산
pop_masan_dongbu = 191289
pop_masan_jungbu = 175716

## 창원
## 창원 서부
pop_changwon_seobu20 = pd.read_csv('../finalproject/KOSIS/changwon/changwon_seobu_20.csv', encoding='cp949')
pop_changwon_seobu20 = pop_changwon_seobu20.rename(columns=pop_changwon_seobu20.iloc[0])
pop_changwon_seobu20 = pop_changwon_seobu20.drop(pop_changwon_seobu20.index[0])
pop_changwon_seobu20 = pop_changwon_seobu20[pop_changwon_seobu20['5세별']=='계']
pop_changwon_seobu20 = pop_changwon_seobu20.iloc[:,2].astype(int).sum()


## 창원 중부
pop_changwon_jungbu20 = pd.read_csv('../finalproject/KOSIS/changwon/changwon_jungbu_20.csv', encoding='cp949')
pop_changwon_jungbu20 = pop_changwon_jungbu20.rename(columns=pop_changwon_jungbu20.iloc[0])
pop_changwon_jungbu20 = pop_changwon_jungbu20.drop(pop_changwon_jungbu20.index[0])
pop_changwon_jungbu20 = pop_changwon_jungbu20[pop_changwon_jungbu20['5세별']=='계']
pop_changwon_jungbu20 = pop_changwon_jungbu20.iloc[:,2].astype(int).sum()


## 진해
pop_jinhae = 192755

## 진주
pop_jinju = 348096

# %%
not_seoul = pd.DataFrame({'jur_stn':['충남세종경찰서','경기수원중부경찰서','경기수원남부경찰서',
                                     '경기수원서부경찰서','경남마산동부경찰서','경남마산중부경찰서',
                                     '경남창원서부경찰서','경남창원중부경찰서','경남진해경찰서',
                                     '경남진주경찰서'],
             '총인구수 (명)':[sejong,pop_suwon_jungbu20,pop_suwon_nambu20,pop_suwon_seobu20,
                        pop_masan_dongbu,pop_masan_jungbu,pop_changwon_seobu20,pop_changwon_jungbu20,
                        pop_jinhae,pop_jinju]})

# %%
aa = pd.concat([twopop,pop_2020,not_seoul],axis=0)
aa.to_csv('C:/hnooee/pythonwork/finalproject/총 인구 2020.csv',encoding='euc-kr')
