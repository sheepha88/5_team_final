# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### 성별 인구

# %%
pop = pd.read_csv('../finalproject/SBJ_2107_004/14.5개시도_성연령별_총인구분포.csv')

# %%
## 불필요한 데이터 삭제

pop = pop[pop.age=='합계']

# %%
pop_seoul = pop[pop['sido'].str.contains('서울', na=False)]
pop_sejong = pop[pop['sido'].str.contains('세종특별', na=False)]
pop_suwon = pop[pop['sgg_nm'].str.contains('수원시', na=False)]
pop_changwon = pop[pop['sgg_nm'].str.contains('창원시', na=False)]
pop_jinju = pop[pop['sgg_nm'].str.contains('진주시', na=False)]

# %%
## 하나의 구에 두개의 관할서가 있는 경우

## 강남구
## 수서경찰서
pop_seoul_suseo17 = pd.read_csv('../finalproject/KOSIS/seoul/suseo_17.csv', encoding='cp949')
pop_seoul_suseo17 = pop_seoul_suseo17.rename(columns=pop_seoul_suseo17.iloc[0])
pop_seoul_suseo17 = pop_seoul_suseo17.drop(pop_seoul_suseo17.index[0])
pop_seoul_suseo17 = pop_seoul_suseo17[pop_seoul_suseo17['5세별']=='계']
pop_seoul_suseo17 = pop_seoul_suseo17.iloc[:,2].astype(int)

pop_seoul_suseo18 = pd.read_csv('../finalproject/KOSIS/seoul/suseo_18.csv', encoding='cp949')
pop_seoul_suseo18 = pop_seoul_suseo18.rename(columns=pop_seoul_suseo18.iloc[0])
pop_seoul_suseo18 = pop_seoul_suseo18.drop(pop_seoul_suseo18.index[0])
pop_seoul_suseo18 = pop_seoul_suseo18[pop_seoul_suseo18['5세별']=='계']
pop_seoul_suseo18 = pop_seoul_suseo18.iloc[:,2].astype(int)

pop_seoul_suseo19 = pd.read_csv('../finalproject/KOSIS/seoul/suseo_19.csv', encoding='cp949')
pop_seoul_suseo19 =pop_seoul_suseo19.rename(columns=pop_seoul_suseo19.iloc[0])
pop_seoul_suseo19 = pop_seoul_suseo19.drop(pop_seoul_suseo19.index[0])
pop_seoul_suseo19 = pop_seoul_suseo19[pop_seoul_suseo19['5세별']=='계']
pop_seoul_suseo19 = pop_seoul_suseo19.iloc[:,2].astype(int)

pop_seoul_suseo = pd.DataFrame({'jur_stn':['서울수서경찰서','서울수서경찰서','서울수서경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_seoul_suseo17.sum(),pop_seoul_suseo18.sum(),pop_seoul_suseo19.sum()]})


## 강남경찰서
pop_seoul_gangnam17 = pd.read_csv('../finalproject/KOSIS/seoul/gangnam_17.csv', encoding='cp949')
pop_seoul_gangnam17 = pop_seoul_gangnam17.rename(columns=pop_seoul_gangnam17.iloc[0])
pop_seoul_gangnam17 = pop_seoul_gangnam17.drop(pop_seoul_gangnam17.index[0])
pop_seoul_gangnam17 = pop_seoul_gangnam17[pop_seoul_gangnam17['5세별']=='계']
pop_seoul_gangnam17 = pop_seoul_gangnam17.iloc[:,2].astype(int)

pop_seoul_gangnam18 = pd.read_csv('../finalproject/KOSIS/seoul/gangnam_18.csv', encoding='cp949')
pop_seoul_gangnam18 = pop_seoul_gangnam18.rename(columns=pop_seoul_gangnam18.iloc[0])
pop_seoul_gangnam18 = pop_seoul_gangnam18.drop(pop_seoul_gangnam18.index[0])
pop_seoul_gangnam18 = pop_seoul_gangnam18[pop_seoul_gangnam18['5세별']=='계']
pop_seoul_gangnam18 = pop_seoul_gangnam18.iloc[:,2].astype(int)

pop_seoul_gangnam19 = pd.read_csv('../finalproject/KOSIS/seoul/gangnam_19.csv', encoding='cp949')
pop_seoul_gangnam19 = pop_seoul_gangnam19.rename(columns=pop_seoul_gangnam19.iloc[0])
pop_seoul_gangnam19 = pop_seoul_gangnam19.drop(pop_seoul_gangnam19.index[0])
pop_seoul_gangnam19 = pop_seoul_gangnam19[pop_seoul_gangnam19['5세별']=='계']
pop_seoul_gangnam19 = pop_seoul_gangnam19.iloc[:,2].astype(int)

pop_seoul_gangnam = pd.DataFrame({'jur_stn':['서울강남경찰서','서울강남경찰서','서울강남경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_seoul_gangnam17.sum(),pop_seoul_gangnam18.sum(),pop_seoul_gangnam19.sum()]})


## 종로구
## 종로경찰서
pop_seoul_jongro17 = pd.read_csv('../finalproject/KOSIS/seoul/jongro_17.csv', encoding='cp949')
pop_seoul_jongro17 = pop_seoul_jongro17.rename(columns=pop_seoul_jongro17.iloc[0])
pop_seoul_jongro17 = pop_seoul_jongro17.drop(pop_seoul_jongro17.index[0])
pop_seoul_jongro17 = pop_seoul_jongro17[pop_seoul_jongro17['5세별']=='계']
pop_seoul_jongro17 = pop_seoul_jongro17.iloc[:,2].astype(int)

pop_seoul_jongro18 = pd.read_csv('../finalproject/KOSIS/seoul/jongro_18.csv', encoding='cp949')
pop_seoul_jongro18 = pop_seoul_jongro18.rename(columns=pop_seoul_jongro18.iloc[0])
pop_seoul_jongro18 = pop_seoul_jongro18.drop(pop_seoul_jongro18.index[0])
pop_seoul_jongro18 = pop_seoul_jongro18[pop_seoul_jongro18['5세별']=='계']
pop_seoul_jongro18 = pop_seoul_jongro18.iloc[:,2].astype(int)

pop_seoul_jongro19 = pd.read_csv('../finalproject/KOSIS/seoul/jongro_19.csv', encoding='cp949')
pop_seoul_jongro19 = pop_seoul_jongro19.rename(columns=pop_seoul_jongro19.iloc[0])
pop_seoul_jongro19 = pop_seoul_jongro19.drop(pop_seoul_jongro19.index[0])
pop_seoul_jongro19 = pop_seoul_jongro19[pop_seoul_jongro19['5세별']=='계']
pop_seoul_jongro19 = pop_seoul_jongro19.iloc[:,2].astype(int)

pop_seoul_jongro = pd.DataFrame({'jur_stn':['서울종로경찰서','서울종로경찰서','서울종로경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_seoul_jongro17.sum(),pop_seoul_jongro18.sum(),pop_seoul_jongro19.sum()]})


## 혜화경찰서
pop_seoul_hyehwa17 = pd.read_csv('../finalproject/KOSIS/seoul/hyehwa_17.csv', encoding='cp949')
pop_seoul_hyehwa17 = pop_seoul_hyehwa17.rename(columns=pop_seoul_hyehwa17.iloc[0])
pop_seoul_hyehwa17 = pop_seoul_hyehwa17.drop(pop_seoul_hyehwa17.index[0])
pop_seoul_hyehwa17 = pop_seoul_hyehwa17[pop_seoul_hyehwa17['5세별']=='계']
pop_seoul_hyehwa17 = pop_seoul_hyehwa17.iloc[:,2].astype(int)

pop_seoul_hyehwa18 = pd.read_csv('../finalproject/KOSIS/seoul/hyehwa_18.csv', encoding='cp949')
pop_seoul_hyehwa18 = pop_seoul_hyehwa18.rename(columns=pop_seoul_hyehwa18.iloc[0])
pop_seoul_hyehwa18 = pop_seoul_hyehwa18.drop(pop_seoul_hyehwa18.index[0])
pop_seoul_hyehwa18 = pop_seoul_hyehwa18[pop_seoul_hyehwa18['5세별']=='계']
pop_seoul_hyehwa18 = pop_seoul_hyehwa18.iloc[:,2].astype(int)

pop_seoul_hyehwa19 = pd.read_csv('../finalproject/KOSIS/seoul/hyehwa_19.csv', encoding='cp949')
pop_seoul_hyehwa19 = pop_seoul_hyehwa19.rename(columns=pop_seoul_hyehwa19.iloc[0])
pop_seoul_hyehwa19 = pop_seoul_hyehwa19.drop(pop_seoul_hyehwa19.index[0])
pop_seoul_hyehwa19 = pop_seoul_hyehwa19[pop_seoul_hyehwa19['5세별']=='계']
pop_seoul_hyehwa19 = pop_seoul_hyehwa19.iloc[:,2].astype(int)

pop_seoul_hyehwa = pd.DataFrame({'jur_stn':['서울혜화경찰서','서울혜화경찰서','서울혜화경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_seoul_hyehwa17.sum(),pop_seoul_hyehwa18.sum(),pop_seoul_hyehwa19.sum()]})


## 중구
## 남대문경찰서
pop_seoul_namdaemun17 = pd.read_csv('../finalproject/KOSIS/seoul/namdaemun_17.csv', encoding='cp949')
pop_seoul_namdaemun17 = pop_seoul_namdaemun17.rename(columns=pop_seoul_namdaemun17.iloc[0])
pop_seoul_namdaemun17 = pop_seoul_namdaemun17.drop(pop_seoul_namdaemun17.index[0])
pop_seoul_namdaemun17 = pop_seoul_namdaemun17[pop_seoul_namdaemun17['5세별']=='계']
pop_seoul_namdaemun17 = pop_seoul_namdaemun17.iloc[:,2].astype(int)

pop_seoul_namdaemun18 = pd.read_csv('../finalproject/KOSIS/seoul/namdaemun_18.csv', encoding='cp949')
pop_seoul_namdaemun18 = pop_seoul_namdaemun18.rename(columns=pop_seoul_namdaemun18.iloc[0])
pop_seoul_namdaemun18 = pop_seoul_namdaemun18.drop(pop_seoul_namdaemun18.index[0])
pop_seoul_namdaemun18 = pop_seoul_namdaemun18[pop_seoul_namdaemun18['5세별']=='계']
pop_seoul_namdaemun18 = pop_seoul_namdaemun18.iloc[:,2].astype(int)

pop_seoul_namdaemun19 = pd.read_csv('../finalproject/KOSIS/seoul/namdaemun_19.csv', encoding='cp949')
pop_seoul_namdaemun19 = pop_seoul_namdaemun19.rename(columns=pop_seoul_namdaemun19.iloc[0])
pop_seoul_namdaemun19 = pop_seoul_namdaemun19.drop(pop_seoul_namdaemun19.index[0])
pop_seoul_namdaemun19 = pop_seoul_namdaemun19[pop_seoul_namdaemun19['5세별']=='계']
pop_seoul_namdaemun19 = pop_seoul_namdaemun19.iloc[:,2].astype(int)

pop_seoul_namdaemun = pd.DataFrame({'jur_stn':['서울남대문경찰서','서울남대문경찰서','서울남대문경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_seoul_hyehwa17.sum(),pop_seoul_hyehwa18.sum(),pop_seoul_namdaemun19.sum()]})


## 중부경찰서
pop_seoul_jungbu17 = pd.read_csv('../finalproject/KOSIS/seoul/jungbu_17.csv', encoding='cp949')
pop_seoul_jungbu17 = pop_seoul_jungbu17.rename(columns=pop_seoul_jungbu17.iloc[0])
pop_seoul_jungbu17 = pop_seoul_jungbu17.drop(pop_seoul_jungbu17.index[0])
pop_seoul_jungbu17 = pop_seoul_jungbu17[pop_seoul_jungbu17['5세별']=='계']
pop_seoul_jungbu17 = pop_seoul_jungbu17.iloc[:,2].astype(int)

pop_seoul_jungbu18 = pd.read_csv('../finalproject/KOSIS/seoul/jungbu_18.csv', encoding='cp949')
pop_seoul_jungbu18 = pop_seoul_jungbu18.rename(columns=pop_seoul_jungbu18.iloc[0])
pop_seoul_jungbu18 = pop_seoul_jungbu18.drop(pop_seoul_jungbu18.index[0])
pop_seoul_jungbu18 = pop_seoul_jungbu18[pop_seoul_jungbu18['5세별']=='계']
pop_seoul_jungbu18 = pop_seoul_jungbu18.iloc[:,2].astype(int)

pop_seoul_jungbu19 = pd.read_csv('../finalproject/KOSIS/seoul/jungbu_19.csv', encoding='cp949')
pop_seoul_jungbu19 = pop_seoul_jungbu19.rename(columns=pop_seoul_jungbu19.iloc[0])
pop_seoul_jungbu19 = pop_seoul_jungbu19.drop(pop_seoul_jungbu19.index[0])
pop_seoul_jungbu19 = pop_seoul_jungbu19[pop_seoul_jungbu19['5세별']=='계']
pop_seoul_jungbu19 = pop_seoul_jungbu19.iloc[:,2].astype(int)

pop_seoul_jungbu = pd.DataFrame({'jur_stn':['서울중부경찰서','서울중부경찰서','서울중부경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_seoul_jungbu17.sum(),pop_seoul_jungbu18.sum(),pop_seoul_jungbu19.sum()]})

## 서초구
## 방배경찰서
pop_seoul_bangbae17 = pd.read_csv('../finalproject/KOSIS/seoul/bangbae_17.csv', encoding='cp949')
pop_seoul_bangbae17 = pop_seoul_bangbae17.rename(columns=pop_seoul_bangbae17.iloc[0])
pop_seoul_bangbae17 = pop_seoul_bangbae17.drop(pop_seoul_bangbae17.index[0])
pop_seoul_bangbae17 = pop_seoul_bangbae17[pop_seoul_bangbae17['5세별']=='계']
pop_seoul_bangbae17 = pop_seoul_bangbae17.iloc[:,2].astype(int)

pop_seoul_bangbae18 = pd.read_csv('../finalproject/KOSIS/seoul/bangbae_18.csv', encoding='cp949')
pop_seoul_bangbae18 = pop_seoul_bangbae18.rename(columns=pop_seoul_bangbae18.iloc[0])
pop_seoul_bangbae18 = pop_seoul_bangbae18.drop(pop_seoul_bangbae18.index[0])
pop_seoul_bangbae18 = pop_seoul_bangbae18[pop_seoul_bangbae18['5세별']=='계']
pop_seoul_bangbae18 = pop_seoul_bangbae18.iloc[:,2].astype(int)

pop_seoul_bangbae19 = pd.read_csv('../finalproject/KOSIS/seoul/bangbae_19.csv', encoding='cp949')
pop_seoul_bangbae19 = pop_seoul_bangbae19.rename(columns=pop_seoul_bangbae19.iloc[0])
pop_seoul_bangbae19 = pop_seoul_bangbae19.drop(pop_seoul_bangbae19.index[0])
pop_seoul_bangbae19 = pop_seoul_bangbae19[pop_seoul_bangbae19['5세별']=='계']
pop_seoul_bangbae19 = pop_seoul_bangbae19.iloc[:,2].astype(int)

pop_seoul_bangbae = pd.DataFrame({'jur_stn':['서울방배경찰서','서울방배경찰서','서울방배경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_seoul_bangbae17.sum(),pop_seoul_bangbae18.sum(),pop_seoul_bangbae19.sum()]})



## 서초경찰서
pop_seoul_seocho17 = pd.read_csv('../finalproject/KOSIS/seoul/seocho_17.csv', encoding='cp949')
pop_seoul_seocho17 = pop_seoul_seocho17.rename(columns=pop_seoul_seocho17.iloc[0])
pop_seoul_seocho17 = pop_seoul_seocho17.drop(pop_seoul_seocho17.index[0])
pop_seoul_seocho17 = pop_seoul_seocho17[pop_seoul_seocho17['5세별']=='계']
pop_seoul_seocho17 = pop_seoul_seocho17.iloc[:,2].astype(int)

pop_seoul_seocho18 = pd.read_csv('../finalproject/KOSIS/seoul/seocho_18.csv', encoding='cp949')
pop_seoul_seocho18 = pop_seoul_seocho18.rename(columns=pop_seoul_seocho18.iloc[0])
pop_seoul_seocho18 = pop_seoul_seocho18.drop(pop_seoul_seocho18.index[0])
pop_seoul_seocho18 = pop_seoul_seocho18[pop_seoul_seocho18['5세별']=='계']
pop_seoul_seocho18 = pop_seoul_seocho18.iloc[:,2].astype(int)

pop_seoul_seocho19 = pd.read_csv('../finalproject/KOSIS/seoul/seocho_19.csv', encoding='cp949')
pop_seoul_seocho19 = pop_seoul_seocho19.rename(columns=pop_seoul_seocho19.iloc[0])
pop_seoul_seocho19 = pop_seoul_seocho19.drop(pop_seoul_seocho19.index[0])
pop_seoul_seocho19 = pop_seoul_seocho19[pop_seoul_seocho19['5세별']=='계']
pop_seoul_seocho19 = pop_seoul_seocho19.iloc[:,2].astype(int)

pop_seoul_seocho = pd.DataFrame({'jur_stn':['서울서초경찰서','서울서초경찰서','서울서초경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_seoul_seocho17.sum(),pop_seoul_seocho18.sum(),pop_seoul_seocho19.sum()]})


## 은평구
## 서부경찰서
pop_seoul_seobu17 = pd.read_csv('../finalproject/KOSIS/seoul/seobu_17.csv', encoding='cp949')
pop_seoul_seobu17 = pop_seoul_seobu17.rename(columns=pop_seoul_seobu17.iloc[0])
pop_seoul_seobu17 = pop_seoul_seobu17.drop(pop_seoul_seobu17.index[0])
pop_seoul_seobu17 = pop_seoul_seobu17[pop_seoul_seobu17['5세별']=='계']
pop_seoul_seobu17 = pop_seoul_seobu17.iloc[:,2].astype(int)

pop_seoul_seobu18 = pd.read_csv('../finalproject/KOSIS/seoul/seobu_18.csv', encoding='cp949')
pop_seoul_seobu18 = pop_seoul_seobu18.rename(columns=pop_seoul_seobu18.iloc[0])
pop_seoul_seobu18 = pop_seoul_seobu18.drop(pop_seoul_seobu18.index[0])
pop_seoul_seobu18 = pop_seoul_seobu18[pop_seoul_seobu18['5세별']=='계']
pop_seoul_seobu18 = pop_seoul_seobu18.iloc[:,2].astype(int)

pop_seoul_seobu19 = pd.read_csv('../finalproject/KOSIS/seoul/seobu_19.csv', encoding='cp949')
pop_seoul_seobu19 = pop_seoul_seobu19.rename(columns=pop_seoul_seobu19.iloc[0])
pop_seoul_seobu19 = pop_seoul_seobu19.drop(pop_seoul_seobu19.index[0])
pop_seoul_seobu19 = pop_seoul_seobu19[pop_seoul_seobu19['5세별']=='계']
pop_seoul_seobu19 = pop_seoul_seobu19.iloc[:,2].astype(int)

pop_seoul_seobu = pd.DataFrame({'jur_stn':['서울서부경찰서','서울서부경찰서','서울서부경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_seoul_seobu17.sum(),pop_seoul_seobu18.sum(),pop_seoul_seobu19.sum()]})


## 은평경찰서
pop_seoul_eunpyeong17 = pd.read_csv('../finalproject/KOSIS/seoul/eunpyeong_17.csv', encoding='cp949')
pop_seoul_eunpyeong17 = pop_seoul_eunpyeong17.rename(columns=pop_seoul_eunpyeong17.iloc[0])
pop_seoul_eunpyeong17 = pop_seoul_eunpyeong17.drop(pop_seoul_eunpyeong17.index[0])
pop_seoul_eunpyeong17 = pop_seoul_eunpyeong17[pop_seoul_eunpyeong17['5세별']=='계']
pop_seoul_eunpyeong17 = pop_seoul_eunpyeong17.iloc[:,2].astype(int)

pop_seoul_eunpyeong18 = pd.read_csv('../finalproject/KOSIS/seoul/eunpyeong_18.csv', encoding='cp949')
pop_seoul_eunpyeong18 = pop_seoul_eunpyeong18.rename(columns=pop_seoul_eunpyeong18.iloc[0])
pop_seoul_eunpyeong18 = pop_seoul_eunpyeong18.drop(pop_seoul_eunpyeong18.index[0])
pop_seoul_eunpyeong18 = pop_seoul_eunpyeong18[pop_seoul_eunpyeong18['5세별']=='계']
pop_seoul_eunpyeong18 = pop_seoul_eunpyeong18.iloc[:,2].astype(int)

pop_seoul_eunpyeong19 = pd.read_csv('../finalproject/KOSIS/seoul/eunpyeong_19.csv', encoding='cp949')
pop_seoul_eunpyeong19 = pop_seoul_eunpyeong19.rename(columns=pop_seoul_eunpyeong19.iloc[0])
pop_seoul_eunpyeong19 = pop_seoul_eunpyeong19.drop(pop_seoul_eunpyeong19.index[0])
pop_seoul_eunpyeong19 = pop_seoul_eunpyeong19[pop_seoul_eunpyeong19['5세별']=='계']
pop_seoul_eunpyeong19 = pop_seoul_eunpyeong19.iloc[:,2].astype(int)

pop_seoul_eunpyeong = pd.DataFrame({'jur_stn':['서울은평경찰서','서울은평경찰서','서울은평경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_seoul_eunpyeong17.sum(),pop_seoul_eunpyeong18.sum(),pop_seoul_eunpyeong19.sum()]})


## 성북구
## 성북경찰서
pop_seoul_sungbuk17 = pd.read_csv('../finalproject/KOSIS/seoul/sungbuk_17.csv', encoding='cp949')
pop_seoul_sungbuk17 = pop_seoul_sungbuk17.rename(columns=pop_seoul_sungbuk17.iloc[0])
pop_seoul_sungbuk17 = pop_seoul_sungbuk17.drop(pop_seoul_sungbuk17.index[0])
pop_seoul_sungbuk17 = pop_seoul_sungbuk17[pop_seoul_sungbuk17['5세별']=='계']
pop_seoul_sungbuk17 = pop_seoul_sungbuk17.iloc[:,2].astype(int)

pop_seoul_sungbuk18 = pd.read_csv('../finalproject/KOSIS/seoul/sungbuk_18.csv', encoding='cp949')
pop_seoul_sungbuk18 = pop_seoul_sungbuk18.rename(columns=pop_seoul_sungbuk18.iloc[0])
pop_seoul_sungbuk18 = pop_seoul_sungbuk18.drop(pop_seoul_sungbuk18.index[0])
pop_seoul_sungbuk18 = pop_seoul_sungbuk18[pop_seoul_sungbuk18['5세별']=='계']
pop_seoul_sungbuk18 = pop_seoul_sungbuk18.iloc[:,2].astype(int)

pop_seoul_sungbuk19 = pd.read_csv('../finalproject/KOSIS/seoul/sungbuk_19.csv', encoding='cp949')
pop_seoul_sungbuk19 = pop_seoul_sungbuk19.rename(columns=pop_seoul_sungbuk19.iloc[0])
pop_seoul_sungbuk19 = pop_seoul_sungbuk19.drop(pop_seoul_sungbuk19.index[0])
pop_seoul_sungbuk19 = pop_seoul_sungbuk19[pop_seoul_sungbuk19['5세별']=='계']
pop_seoul_sungbuk19 = pop_seoul_sungbuk19.iloc[:,2].astype(int)

pop_seoul_sungbuk = pd.DataFrame({'jur_stn':['서울성북경찰서','서울성북경찰서','서울성북경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_seoul_sungbuk17.sum(),pop_seoul_sungbuk18.sum(),pop_seoul_sungbuk19.sum()]})


## 종암경찰서
pop_seoul_jongam17 = pd.read_csv('../finalproject/KOSIS/seoul/jongam_17.csv', encoding='cp949')
pop_seoul_jongam17 = pop_seoul_jongam17.rename(columns=pop_seoul_jongam17.iloc[0])
pop_seoul_jongam17 = pop_seoul_jongam17.drop(pop_seoul_jongam17.index[0])
pop_seoul_jongam17 = pop_seoul_jongam17[pop_seoul_jongam17['5세별']=='계']
pop_seoul_jongam17 = pop_seoul_jongam17.iloc[:,2].astype(int)

pop_seoul_jongam18 = pd.read_csv('../finalproject/KOSIS/seoul/jongam_18.csv', encoding='cp949')
pop_seoul_jongam18 = pop_seoul_jongam18.rename(columns=pop_seoul_jongam18.iloc[0])
pop_seoul_jongam18 = pop_seoul_jongam18.drop(pop_seoul_jongam18.index[0])
pop_seoul_jongam18 = pop_seoul_jongam18[pop_seoul_jongam18['5세별']=='계']
pop_seoul_jongam18 = pop_seoul_jongam18.iloc[:,2].astype(int)

pop_seoul_jongam19 = pd.read_csv('../finalproject/KOSIS/seoul/jongam_19.csv', encoding='cp949')
pop_seoul_jongam19 = pop_seoul_jongam19.rename(columns=pop_seoul_jongam19.iloc[0])
pop_seoul_jongam19 = pop_seoul_jongam19.drop(pop_seoul_jongam19.index[0])
pop_seoul_jongam19 = pop_seoul_jongam19[pop_seoul_jongam19['5세별']=='계']
pop_seoul_jongam19 = pop_seoul_jongam19.iloc[:,2].astype(int)

pop_seoul_jongam = pd.DataFrame({'jur_stn':['서울종암경찰서','서울종암경찰서','서울종암경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_seoul_jongam17.sum(),pop_seoul_jongam18.sum(),pop_seoul_jongam19.sum()]})

# %%
## 서울시 자치구별 분류

pop_seoul_gangseo = pop_seoul[pop_seoul['sgg_nm'].str.contains('강서구', na=False)]
pop_seoul_gangseo = pop_seoul_gangseo.loc[:,['date', 'popu_num']]
pop_seoul_gangseo = pop_seoul_gangseo.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_gangseo['jur_stn']=['서울강서경찰서','서울강서경찰서','서울강서경찰서']
pop_seoul_gangseo = pop_seoul_gangseo[['jur_stn','연도','총 인구수']]

pop_seoul_jungrang = pop_seoul[pop_seoul['sgg_nm'].str.contains('중랑구', na=False)]
pop_seoul_jungrang = pop_seoul_jungrang.loc[:,['date', 'popu_num']]
pop_seoul_jungrang = pop_seoul_jungrang.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_jungrang['jur_stn']=['서울중랑경찰서','서울중랑경찰서','서울중랑경찰서']
pop_seoul_jungrang = pop_seoul_jungrang[['jur_stn','연도','총 인구수']]

pop_seoul_dongjak = pop_seoul[pop_seoul['sgg_nm'].str.contains('동작구', na=False)]
pop_seoul_dongjak = pop_seoul_dongjak.loc[:,['date', 'popu_num']]
pop_seoul_dongjak = pop_seoul_dongjak.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_dongjak['jur_stn']=['서울동작경찰서','서울동작경찰서','서울동작경찰서']
pop_seoul_dongjak = pop_seoul_dongjak[['jur_stn','연도','총 인구수']]

pop_seoul_gangdong = pop_seoul[pop_seoul['sgg_nm'].str.contains('강동구', na=False)]
pop_seoul_gangdong = pop_seoul_gangdong.loc[:,['date', 'popu_num']]
pop_seoul_gangdong = pop_seoul_gangdong.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_gangdong['jur_stn']=['서울강동경찰서','서울강동경찰서','서울강동경찰서']
pop_seoul_gangdong = pop_seoul_gangdong[['jur_stn','연도','총 인구수']]

pop_seoul_gangbuk = pop_seoul[pop_seoul['sgg_nm'].str.contains('강북구', na=False)]
pop_seoul_gangbuk = pop_seoul_gangbuk.loc[:,['date', 'popu_num']]
pop_seoul_gangbuk = pop_seoul_gangbuk.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_gangbuk['jur_stn']=['서울강북경찰서','서울강북경찰서','서울강북경찰서']
pop_seoul_gangbuk = pop_seoul_gangbuk[['jur_stn','연도','총 인구수']]

pop_seoul_gwanak = pop_seoul[pop_seoul['sgg_nm'].str.contains('관악구', na=False)]
pop_seoul_gwanak = pop_seoul_gwanak.loc[:,['date', 'popu_num']]
pop_seoul_gwanak = pop_seoul_gwanak.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_gwanak['jur_stn']=['서울관악경찰서','서울관악경찰서','서울관악경찰서']
pop_seoul_gwanak = pop_seoul_gwanak[['jur_stn','연도','총 인구수']]

pop_seoul_gwangjin = pop_seoul[pop_seoul['sgg_nm'].str.contains('광진구', na=False)]
pop_seoul_gwangjin = pop_seoul_gwangjin.loc[:,['date', 'popu_num']]
pop_seoul_gwangjin = pop_seoul_gwangjin.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_gwangjin['jur_stn']=['서울광진경찰서','서울광진경찰서','서울광진경찰서']
pop_seoul_gwangjin = pop_seoul_gwangjin[['jur_stn','연도','총 인구수']]

pop_seoul_guro = pop_seoul[pop_seoul['sgg_nm'].str.contains('구로구', na=False)]
pop_seoul_guro = pop_seoul_guro.loc[:,['date', 'popu_num']]
pop_seoul_guro = pop_seoul_guro.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_guro['jur_stn']=['서울구로경찰서','서울구로경찰서','서울구로경찰서']
pop_seoul_guro = pop_seoul_guro[['jur_stn','연도','총 인구수']]

pop_seoul_geumchun = pop_seoul[pop_seoul['sgg_nm'].str.contains('금천구', na=False)]
pop_seoul_geumchun = pop_seoul_geumchun.loc[:,['date', 'popu_num']]
pop_seoul_geumchun = pop_seoul_geumchun.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_geumchun['jur_stn']=['서울금천경찰서','서울금천경찰서','서울금천경찰서']
pop_seoul_geumchun = pop_seoul_geumchun[['jur_stn','연도','총 인구수']]

pop_seoul_nowon = pop_seoul[pop_seoul['sgg_nm'].str.contains('노원구', na=False)]
pop_seoul_nowon = pop_seoul_nowon.loc[:,['date', 'popu_num']]
pop_seoul_nowon = pop_seoul_nowon.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_nowon['jur_stn']=['서울노원경찰서','서울노원경찰서','서울노원경찰서']
pop_seoul_nowon = pop_seoul_nowon[['jur_stn','연도','총 인구수']]

pop_seoul_dobong = pop_seoul[pop_seoul['sgg_nm'].str.contains('도봉구', na=False)]
pop_seoul_dobong = pop_seoul_dobong.loc[:,['date', 'popu_num']]
pop_seoul_dobong = pop_seoul_dobong.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_dobong['jur_stn']=['서울도봉경찰서','서울도봉경찰서','서울도봉경찰서']
pop_seoul_dobong = pop_seoul_dobong[['jur_stn','연도','총 인구수']]

pop_seoul_dongdaemun = pop_seoul[pop_seoul['sgg_nm'].str.contains('동대문구', na=False)]
pop_seoul_dongdaemun = pop_seoul_dongdaemun.loc[:,['date', 'popu_num']]
pop_seoul_dongdaemun = pop_seoul_dongdaemun.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_dongdaemun['jur_stn']=['서울동대문경찰서','서울동대문경찰서','서울동대문경찰서']
pop_seoul_dongdaemun = pop_seoul_dongdaemun[['jur_stn','연도','총 인구수']]

pop_seoul_mapo = pop_seoul[pop_seoul['sgg_nm'].str.contains('마포구', na=False)]
pop_seoul_mapo = pop_seoul_mapo.loc[:,['date', 'popu_num']]
pop_seoul_mapo = pop_seoul_mapo.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_mapo['jur_stn']=['서울마포경찰서','서울마포경찰서','서울마포경찰서']
pop_seoul_mapo = pop_seoul_mapo[['jur_stn','연도','총 인구수']]

pop_seoul_seodaemun = pop_seoul[pop_seoul['sgg_nm'].str.contains('서대문구', na=False)]
pop_seoul_seodaemun = pop_seoul_seodaemun.loc[:,['date', 'popu_num']]
pop_seoul_seodaemun = pop_seoul_seodaemun.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_seodaemun['jur_stn']=['서울서대문경찰서','서울서대문경찰서','서울서대문경찰서']
pop_seoul_seodaemun = pop_seoul_seodaemun[['jur_stn','연도','총 인구수']]

pop_seoul_sungdong = pop_seoul[pop_seoul['sgg_nm'].str.contains('성동구', na=False)]
pop_seoul_sungdong = pop_seoul_sungdong.loc[:,['date', 'popu_num']]
pop_seoul_sungdong = pop_seoul_sungdong.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_sungdong['jur_stn']=['서울성동경찰서','서울성동경찰서','서울성동경찰서']
pop_seoul_sungdong = pop_seoul_sungdong[['jur_stn','연도','총 인구수']]

pop_seoul_songpa = pop_seoul[pop_seoul['sgg_nm'].str.contains('송파구', na=False)]
pop_seoul_songpa = pop_seoul_songpa.loc[:,['date', 'popu_num']]
pop_seoul_songpa = pop_seoul_songpa.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_songpa['jur_stn']=['서울송파경찰서','서울송파경찰서','서울송파경찰서']
pop_seoul_songpa = pop_seoul_songpa[['jur_stn','연도','총 인구수']]

pop_seoul_yangchun = pop_seoul[pop_seoul['sgg_nm'].str.contains('양천구', na=False)]
pop_seoul_yangchun = pop_seoul_yangchun.loc[:,['date', 'popu_num']]
pop_seoul_yangchun = pop_seoul_yangchun.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_yangchun['jur_stn']=['서울양천경찰서','서울양천경찰서','서울양천경찰서']
pop_seoul_yangchun = pop_seoul_yangchun[['jur_stn','연도','총 인구수']]

pop_seoul_yungdeongpo = pop_seoul[pop_seoul['sgg_nm'].str.contains('영등포구', na=False)]
pop_seoul_yungdeongpo = pop_seoul_yungdeongpo.loc[:,['date', 'popu_num']]
pop_seoul_yungdeongpo = pop_seoul_yungdeongpo.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_yungdeongpo['jur_stn']=['서울영등포경찰서','서울영등포경찰서','서울영등포경찰서']
pop_seoul_yungdeongpo = pop_seoul_yungdeongpo[['jur_stn','연도','총 인구수']]

pop_seoul_yongsan = pop_seoul[pop_seoul['sgg_nm'].str.contains('용산구', na=False)]
pop_seoul_yongsan = pop_seoul_yongsan.loc[:,['date', 'popu_num']]
pop_seoul_yongsan = pop_seoul_yongsan.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_seoul_yongsan['jur_stn']=['서울용산경찰서','서울용산경찰서','서울용산경찰서']
pop_seoul_yongsan = pop_seoul_yongsan[['jur_stn','연도','총 인구수']]

# %%
## 그외 시 분류

## 세종
pop_sejong = pop[pop['sgg_nm'].str.contains('세종', na=False)]
pop_sejong = pop_sejong.loc[:,['date', 'popu_num']]
pop_sejong = pop_sejong.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_sejong['jur_stn']=['충남세종경찰서','충남세종경찰서','충남세종경찰서']
pop_sejong = pop_sejong[['jur_stn','연도','총 인구수']]

## 수원
## 수원중부경찰서
pop_suwon_jungbu17 = pd.read_csv('../finalproject/KOSIS/suwon/suwon_jungbu_17.csv', encoding='cp949')
pop_suwon_jungbu17 = pop_suwon_jungbu17.rename(columns=pop_suwon_jungbu17.iloc[0])
pop_suwon_jungbu17 = pop_suwon_jungbu17.drop(pop_suwon_jungbu17.index[0])
pop_suwon_jungbu17 = pop_suwon_jungbu17[pop_suwon_jungbu17['5세별']=='계']
pop_suwon_jungbu17 = pop_suwon_jungbu17.iloc[:,2].astype(int)

pop_suwon_jungbu18 = pd.read_csv('../finalproject/KOSIS/suwon/suwon_jungbu_18.csv', encoding='cp949')
pop_suwon_jungbu18 = pop_suwon_jungbu18.rename(columns=pop_suwon_jungbu18.iloc[0])
pop_suwon_jungbu18 = pop_suwon_jungbu18.drop(pop_suwon_jungbu18.index[0])
pop_suwon_jungbu18 = pop_suwon_jungbu18[pop_suwon_jungbu18['5세별']=='계']
pop_suwon_jungbu18 = pop_suwon_jungbu18.iloc[:,2].astype(int)

pop_suwon_jungbu19 = pd.read_csv('../finalproject/KOSIS/suwon/suwon_jungbu_19.csv', encoding='cp949')
pop_suwon_jungbu19 = pop_suwon_jungbu19.rename(columns=pop_suwon_jungbu19.iloc[0])
pop_suwon_jungbu19 = pop_suwon_jungbu19.drop(pop_suwon_jungbu19.index[0])
pop_suwon_jungbu19 = pop_suwon_jungbu19[pop_suwon_jungbu19['5세별']=='계']
pop_suwon_jungbu19 = pop_suwon_jungbu19.iloc[:,2].astype(int)

pop_suwon_jungbu = pd.DataFrame({'jur_stn':['경기수원중부경찰서','경기수원중부경찰서','경기수원중부경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_suwon_jungbu17.sum(),pop_suwon_jungbu18.sum(),pop_suwon_jungbu19.sum()]})


## 수원남부경찰서
pop_suwon_nambu17 = pd.read_csv('../finalproject/KOSIS/suwon/suwon_nambu_17.csv', encoding='cp949')
pop_suwon_nambu17 = pop_suwon_nambu17.rename(columns=pop_suwon_nambu17.iloc[0])
pop_suwon_nambu17 = pop_suwon_nambu17.drop(pop_suwon_nambu17.index[0])
pop_suwon_nambu17 = pop_suwon_nambu17[pop_suwon_nambu17['5세별']=='계']
pop_suwon_nambu17 = pop_suwon_nambu17.iloc[:,2].astype(int)

pop_suwon_nambu18 = pd.read_csv('../finalproject/KOSIS/suwon/suwon_nambu_18.csv', encoding='cp949')
pop_suwon_nambu18 = pop_suwon_nambu18.rename(columns=pop_suwon_nambu18.iloc[0])
pop_suwon_nambu18 = pop_suwon_nambu18.drop(pop_suwon_nambu18.index[0])
pop_suwon_nambu18 = pop_suwon_nambu18[pop_suwon_nambu18['5세별']=='계']
pop_suwon_nambu18 = pop_suwon_nambu18.iloc[:,2].astype(int)

pop_suwon_nambu19 = pd.read_csv('../finalproject/KOSIS/suwon/suwon_nambu_19.csv', encoding='cp949')
pop_suwon_nambu19 = pop_suwon_nambu19.rename(columns=pop_suwon_nambu19.iloc[0])
pop_suwon_nambu19 = pop_suwon_nambu19.drop(pop_suwon_nambu19.index[0])
pop_suwon_nambu19 = pop_suwon_nambu19[pop_suwon_nambu19['5세별']=='계']
pop_suwon_nambu19 = pop_suwon_nambu19.iloc[:,2].astype(int)

pop_suwon_nambu = pd.DataFrame({'jur_stn':['경기수원남부경찰서','경기수원남부경찰서','경기수원남부경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_suwon_nambu17.sum(),pop_suwon_nambu18.sum(),pop_suwon_nambu19.sum()]})



## 수원서부경찰서
pop_suwon_seobu17 = pd.read_csv('../finalproject/KOSIS/suwon/suwon_seobu_17.csv', encoding='cp949')
pop_suwon_seobu17 = pop_suwon_seobu17.rename(columns=pop_suwon_seobu17.iloc[0])
pop_suwon_seobu17 = pop_suwon_seobu17.drop(pop_suwon_seobu17.index[0])
pop_suwon_seobu17 = pop_suwon_seobu17[pop_suwon_seobu17['5세별']=='계']
pop_suwon_seobu17 = pop_suwon_seobu17.iloc[:,2].astype(int)

pop_suwon_seobu18 = pd.read_csv('../finalproject/KOSIS/suwon/suwon_seobu_18.csv', encoding='cp949')
pop_suwon_seobu18 = pop_suwon_seobu18.rename(columns=pop_suwon_seobu18.iloc[0])
pop_suwon_seobu18 = pop_suwon_seobu18.drop(pop_suwon_seobu18.index[0])
pop_suwon_seobu18 = pop_suwon_seobu18[pop_suwon_seobu18['5세별']=='계']
pop_suwon_seobu18 = pop_suwon_seobu18.iloc[:,2].astype(int)

pop_suwon_seobu19 = pd.read_csv('../finalproject/KOSIS/suwon/suwon_seobu_19.csv', encoding='cp949')
pop_suwon_seobu19 = pop_suwon_seobu19.rename(columns=pop_suwon_seobu19.iloc[0])
pop_suwon_seobu19 = pop_suwon_seobu19.drop(pop_suwon_seobu19.index[0])
pop_suwon_seobu19 = pop_suwon_seobu19[pop_suwon_seobu19['5세별']=='계']
pop_suwon_seobu19 = pop_suwon_seobu19.iloc[:,2].astype(int)

pop_suwon_seobu = pd.DataFrame({'jur_stn':['경기수원서부경찰서','경기수원서부경찰서','경기수원서부경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_suwon_seobu17.sum(),pop_suwon_seobu18.sum(),pop_suwon_seobu19.sum()]})



## 마산
pop_masan_dongbu = pop_changwon[pop_changwon['sgg_nm'].str.contains('마산회원구', na=False)]
pop_masan_dongbu = pop_masan_dongbu.loc[:,['date', 'popu_num']]
pop_masan_dongbu = pop_masan_dongbu.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_masan_dongbu['jur_stn']=['경남마산동부경찰서','경남마산동부경찰서','경남마산동부경찰서']
pop_masan_dongbu = pop_masan_dongbu[['jur_stn','연도','총 인구수']]

pop_masan_jungbu = pop_changwon[pop_changwon['sgg_nm'].str.contains('마산합포구', na=False)]
pop_masan_jungbu = pop_masan_jungbu.loc[:,['date', 'popu_num']]
pop_masan_jungbu = pop_masan_dongbu.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_masan_jungbu['jur_stn']=['경남마산중부경찰서','경남마산중부경찰서','경남마산중부경찰서']
pop_masan_jungbu = pop_masan_jungbu[['jur_stn','연도','총 인구수']]

## 창원
## 창원 서부
pop_changwon_seobu17 = pd.read_csv('../finalproject/KOSIS/changwon/changwon_seobu_17.csv', encoding='cp949')
pop_changwon_seobu17 = pop_changwon_seobu17.rename(columns=pop_changwon_seobu17.iloc[0])
pop_changwon_seobu17 = pop_changwon_seobu17.drop(pop_changwon_seobu17.index[0])
pop_changwon_seobu17 = pop_changwon_seobu17[pop_changwon_seobu17['5세별']=='계']
pop_changwon_seobu17 = pop_changwon_seobu17.iloc[:,2].astype(int)

pop_changwon_seobu18 = pd.read_csv('../finalproject/KOSIS/changwon/changwon_seobu_18.csv', encoding='cp949')
pop_changwon_seobu18 = pop_changwon_seobu18.rename(columns=pop_changwon_seobu18.iloc[0])
pop_changwon_seobu18 = pop_changwon_seobu18.drop(pop_changwon_seobu18.index[0])
pop_changwon_seobu18 = pop_changwon_seobu18[pop_changwon_seobu18['5세별']=='계']
pop_changwon_seobu18 = pop_changwon_seobu18.iloc[:,2].astype(int)

pop_changwon_seobu19 = pd.read_csv('../finalproject/KOSIS/changwon/changwon_seobu_19.csv', encoding='cp949')
pop_changwon_seobu19 = pop_changwon_seobu19.rename(columns=pop_changwon_seobu19.iloc[0])
pop_changwon_seobu19 = pop_changwon_seobu19.drop(pop_changwon_seobu19.index[0])
pop_changwon_seobu19 = pop_changwon_seobu19[pop_changwon_seobu19['5세별']=='계']
pop_changwon_seobu19 = pop_changwon_seobu19.iloc[:,2].astype(int)

pop_changwon_seobu = pd.DataFrame({'jur_stn':['경남창원서부경찰서','경남창원서부경찰서','경남창원서부경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_changwon_seobu17.sum(),pop_changwon_seobu18.sum(),pop_changwon_seobu19.sum()]})


## 창원 중부
pop_changwon_jungbu17 = pd.read_csv('../finalproject/KOSIS/changwon/changwon_jungbu_17.csv', encoding='cp949')
pop_changwon_jungbu17 = pop_changwon_jungbu17.rename(columns=pop_changwon_jungbu17.iloc[0])
pop_changwon_jungbu17 = pop_changwon_jungbu17.drop(pop_changwon_jungbu17.index[0])
pop_changwon_jungbu17 = pop_changwon_jungbu17[pop_changwon_jungbu17['5세별']=='계']
pop_changwon_jungbu17 = pop_changwon_jungbu17.iloc[:,2].astype(int)

pop_changwon_jungbu18 = pd.read_csv('../finalproject/KOSIS/changwon/changwon_jungbu_18.csv', encoding='cp949')
pop_changwon_jungbu18 = pop_changwon_jungbu18.rename(columns=pop_changwon_jungbu18.iloc[0])
pop_changwon_jungbu18 = pop_changwon_jungbu18.drop(pop_changwon_jungbu18.index[0])
pop_changwon_jungbu18 = pop_changwon_jungbu18[pop_changwon_jungbu18['5세별']=='계']
pop_changwon_jungbu18 = pop_changwon_jungbu18.iloc[:,2].astype(int)

pop_changwon_jungbu19 = pd.read_csv('../finalproject/KOSIS/changwon/changwon_jungbu_19.csv', encoding='cp949')
pop_changwon_jungbu19 = pop_changwon_jungbu19.rename(columns=pop_changwon_jungbu19.iloc[0])
pop_changwon_jungbu19 = pop_changwon_jungbu19.drop(pop_changwon_jungbu19.index[0])
pop_changwon_jungbu19 = pop_changwon_jungbu19[pop_changwon_jungbu19['5세별']=='계']
pop_changwon_jungbu19 = pop_changwon_jungbu19.iloc[:,2].astype(int)

pop_changwon_jungbu = pd.DataFrame({'jur_stn':['경남창원중부경찰서','경남창원중부경찰서','경남창원중부경찰서'],
                               '연도':[2017,2018,2019],
                               '총 인구수':[pop_changwon_jungbu17.sum(),pop_changwon_jungbu18.sum(),pop_changwon_jungbu19.sum()]})


## 진해
pop_jinhae = pop[pop['sgg_nm'].str.contains('진해', na=False)].loc[:,['date','popu_num']]
pop_jinhae = pop_jinhae.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_jinhae['jur_stn']=['경남진해경찰서','경남진해경찰서','경남진해경찰서']
pop_jinhae = pop_jinhae[['jur_stn','연도','총 인구수']]

## 진주
pop_jinju = pop[pop['sgg_nm'].str.contains('진주', na=False)].loc[:,['date','popu_num']]
pop_jinju = pop_jinju.rename(columns={'date':'연도', 'popu_num':'총 인구수'})
pop_jinju['jur_stn']=['경남진주경찰서','경남진주경찰서','경남진주경찰서']
pop_jinju = pop_jinju[['jur_stn','연도','총 인구수']]

# %%
population = pd.concat([pop_seoul_suseo,
pop_seoul_gangnam,
pop_seoul_jongro,
pop_seoul_hyehwa,
pop_seoul_namdaemun,
pop_seoul_jungbu,
pop_seoul_bangbae,
pop_seoul_seocho,
pop_seoul_seobu,
pop_seoul_eunpyeong,
pop_seoul_sungbuk,
pop_seoul_jongam,
pop_seoul_gangseo,
pop_seoul_jungrang,
pop_seoul_dongjak,
pop_seoul_gangdong,
pop_seoul_gangbuk,
pop_seoul_gwanak,
pop_seoul_gwangjin,
pop_seoul_guro,
pop_seoul_geumchun,
pop_seoul_nowon,
pop_seoul_dobong,
pop_seoul_dongdaemun,
pop_seoul_mapo,
pop_seoul_seodaemun,
pop_seoul_sungdong,
pop_seoul_songpa,
pop_seoul_yangchun,
pop_seoul_yungdeongpo,
pop_seoul_yongsan,
pop_suwon_jungbu,
pop_suwon_seobu,
pop_suwon_nambu,
pop_masan_dongbu,
pop_masan_jungbu,
pop_changwon_jungbu,
pop_changwon_seobu,
pop_jinhae,
pop_jinju,
pop_sejong])

# %%
population.to_csv('C:/hnooee/pythonwork/finalproject/총 인구.csv',encoding='euc-kr')

# %% [markdown]
# ## 모델 성능이 안나와 연령대 고려해야할 때 필요한 코드
# pop_mean = pop[pop.age=='평균연령']
# pop_median = pop[pop.age=='중위연령']
# pop_category = pop[pop['age'].str.contains('~')]
# pop_high = pop[pop['age'].str.contains('이상')]
# pop_low = pop[pop['age'].str.contains('미만')]
#
# pop = pop.drop(pop_total.index)
# pop = pop.drop(pop_mean.index)
# pop = pop.drop(pop_median.index)
# pop = pop.drop(pop_category.index)
# pop = pop.drop(pop_high.index)
# pop = pop.drop(pop_low.index)
#
# (# 세 를 삭제하고 숫자형으로 변경)
# pop['age'] = pop['age'].str.replace("세", "").astype(int)
#
# one = pop[(pop['age']>=14) & (pop['age']<=29)]
# one['age'] = 1
# two = pop[(pop['age']>=30) & (pop['age']<=39)]
# two['age'] = 2
# three = pop[(pop['age']>=40) & (pop['age']<=49)]
# three['age'] = 3
# four = pop[(pop['age']>=50) & (pop['age']<=59)]
# four['age'] = 4
# five = pop[pop['age']>=60]
# five['age'] = 5
# pop = pd.concat([one, two, three, four, five])
#
# (## 연도별 분류(중복되는 구 제외))
#
# pop_seoul_gangseo_17 = pop_seoul_gangseo[pop_seoul_gangseo.date==2017]
# pop_seoul_gangseo_18 = pop_seoul_gangseo[pop_seoul_gangseo.date==2018]
# pop_seoul_gangseo_19 = pop_seoul_gangseo[pop_seoul_gangseo.date==2019]
#
# pop_seoul_jungrang_17 = pop_seoul_jungrang[pop_seoul_jungrang.date==2017]
# pop_seoul_jungrang_18 = pop_seoul_jungrang[pop_seoul_jungrang.date==2018]
# pop_seoul_jungrang_19 = pop_seoul_jungrang[pop_seoul_jungrang.date==2019]
#
# pop_seoul_gangdong_17 = pop_seoul_gangdong[pop_seoul_gangdong.date==2017]
# pop_seoul_gangdong_18 = pop_seoul_gangdong[pop_seoul_gangdong.date==2018]
# pop_seoul_gangdong_19 = pop_seoul_gangdong[pop_seoul_gangdong.date==2019]
#
# pop_seoul_gangbuk_17 = pop_seoul_gangbuk[pop_seoul_gangbuk.date==2017]
# pop_seoul_gangbuk_18 = pop_seoul_gangbuk[pop_seoul_gangbuk.date==2018]
# pop_seoul_gangbuk_19 = pop_seoul_gangbuk[pop_seoul_gangbuk.date==2019]
#
# pop_seoul_gwanak_17 = pop_seoul_gwanak[pop_seoul_gwanak.date==2017]
# pop_seoul_gwanak_18 = pop_seoul_gwanak[pop_seoul_gwanak.date==2018]
# pop_seoul_gwanak_19 = pop_seoul_gwanak[pop_seoul_gwanak.date==2019]
#
# pop_seoul_gwangjin_17 = pop_seoul_gwangjin[pop_seoul_gwangjin.date==2017]
# pop_seoul_gwangjin_18 = pop_seoul_gwangjin[pop_seoul_gwangjin.date==2018]
# pop_seoul_gwangjin_19 = pop_seoul_gwangjin[pop_seoul_gwangjin.date==2019]
#
# pop_seoul_guro_17 = pop_seoul_guro[pop_seoul_guro.date==2017]
# pop_seoul_guro_18 = pop_seoul_guro[pop_seoul_guro.date==2018]
# pop_seoul_guro_19 = pop_seoul_guro[pop_seoul_guro.date==2019]
#
# pop_seoul_geumchun_17 = pop_seoul_geumchun[pop_seoul_geumchun.date==2017]
# pop_seoul_geumchun_18 = pop_seoul_geumchun[pop_seoul_geumchun.date==2018]
# pop_seoul_geumchun_19 = pop_seoul_geumchun[pop_seoul_geumchun.date==2019]
#
# pop_seoul_nowon_17 = pop_seoul_nowon[pop_seoul_nowon.date==2017]
# pop_seoul_nowon_18 = pop_seoul_nowon[pop_seoul_nowon.date==2018]
# pop_seoul_nowon_19 = pop_seoul_nowon[pop_seoul_nowon.date==2019]
#
# pop_seoul_dobong_17 = pop_seoul_dobong[pop_seoul_dobong.date==2017]
# pop_seoul_dobong_18 = pop_seoul_dobong[pop_seoul_dobong.date==2018]
# pop_seoul_dobong_19 = pop_seoul_dobong[pop_seoul_dobong.date==2019]
#
# pop_seoul_dongdaemun_17 = pop_seoul_dongdaemun[pop_seoul_dongdaemun.date==2017]
# pop_seoul_dongdaemun_18 = pop_seoul_dongdaemun[pop_seoul_dongdaemun.date==2018]
# pop_seoul_dongdaemun_19 = pop_seoul_dongdaemun[pop_seoul_dongdaemun.date==2019]
#
# pop_seoul_mapo_17 = pop_seoul_mapo[pop_seoul_mapo.date==2017]
# pop_seoul_mapo_18 = pop_seoul_mapo[pop_seoul_mapo.date==2018]
# pop_seoul_mapo_19 = pop_seoul_mapo[pop_seoul_mapo.date==2019]
#
# pop_seoul_seodaemun_17 = pop_seoul_seodaemun[pop_seoul_seodaemun.date==2017]
# pop_seoul_seodaemun_18 = pop_seoul_seodaemun[pop_seoul_seodaemun.date==2018]
# pop_seoul_seodaemun_19 = pop_seoul_seodaemun[pop_seoul_seodaemun.date==2019]
#
# pop_seoul_sungdong_17 = pop_seoul_sungdong[pop_seoul_sungdong.date==2017]
# pop_seoul_sungdong_18 = pop_seoul_sungdong[pop_seoul_sungdong.date==2018]
# pop_seoul_sungdong_19 = pop_seoul_sungdong[pop_seoul_sungdong.date==2019]
#
# pop_seoul_songpa_17 = pop_seoul_songpa[pop_seoul_songpa.date==2017]
# pop_seoul_songpa_18 = pop_seoul_songpa[pop_seoul_songpa.date==2018]
# pop_seoul_songpa_19 = pop_seoul_songpa[pop_seoul_songpa.date==2019]
#
# pop_seoul_yangchun_17 = pop_seoul_yangchun[pop_seoul_yangchun.date==2017]
# pop_seoul_yangchun_18 = pop_seoul_yangchun[pop_seoul_yangchun.date==2018]
# pop_seoul_yangchun_19 = pop_seoul_yangchun[pop_seoul_yangchun.date==2019]
#
# pop_seoul_yungdeongpo_17 = pop_seoul_yungdeongpo[pop_seoul_yungdeongpo.date==2017]
# pop_seoul_yungdeongpo_18 = pop_seoul_yungdeongpo[pop_seoul_yungdeongpo.date==2018]
# pop_seoul_yungdeongpo_19 = pop_seoul_yungdeongpo[pop_seoul_yungdeongpo.date==2019]
#
# pop_seoul_yongsan_17 = pop_seoul_yongsan[pop_seoul_yongsan.date==2017]
# pop_seoul_yongsan_18 = pop_seoul_yongsan[pop_seoul_yongsan.date==2018]
# pop_seoul_yongsan_19 = pop_seoul_yongsan[pop_seoul_yongsan.date==2019]
