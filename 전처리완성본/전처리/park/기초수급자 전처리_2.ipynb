# %%
import numpy as np
import pandas as pd

# %%
gicho_2017 = pd.read_csv('2017.csv')
gicho_2018 = pd.read_csv('2018.csv')
gicho_2019 = pd.read_csv('2019.csv')
gicho_2020 = pd.read_csv('2019.csv')

# %%
gicho_2017.drop('Unnamed: 0', axis = 1, inplace = True)
gicho_2018.drop('Unnamed: 0', axis = 1, inplace = True)
gicho_2019.drop('Unnamed: 0', axis = 1, inplace = True)
gicho_2020.drop('Unnamed: 0', axis = 1, inplace = True)
gicho_2017 = gicho_2017.rename(columns={'index' : 'police'})
gicho_2018 = gicho_2018.rename(columns={'Unnamed: 0.1' : 'police'})
gicho_2019 = gicho_2019.rename(columns={'Unnamed: 0.1' : 'police'})
gicho_2020 = gicho_2020.rename(columns={'Unnamed: 0.1' : 'police'})
gicho_2017['year'] = 2017
gicho_2018['year'] = 2018
gicho_2019['year'] = 2019
gicho_2020['year'] = 2020

# %%
gicho_2017['police'][3] = '충남세종경찰서'
gicho_2017['police'][6] = '경기수원중부경찰서'
gicho_2017['police'][12] = '경남진주경찰서'
gicho_2017['police'][15] = '경남창원서부경찰서'
gicho_2017['police'][31] = '경기수원남부경찰서'
gicho_2017['police'][33] = '경남창원중부경찰서'
gicho_2017['police'][37] = '경남마산중부경찰서'
gicho_2017['police'][38] = '경남마산동부경찰서'
gicho_2017['police'][39] = '경남진해경찰서'
gicho_2017['police'][40] = '경기수원서부경찰서'
# Out:
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
gicho_2018['police'][3] = '충남세종경찰서'
gicho_2018['police'][6] = '경기수원중부경찰서'
gicho_2018['police'][12] = '경남진주경찰서'
gicho_2018['police'][15] = '경남창원서부경찰서'
gicho_2018['police'][31] = '경기수원남부경찰서'
gicho_2018['police'][33] = '경남창원중부경찰서'
gicho_2018['police'][37] = '경남마산중부경찰서'
gicho_2018['police'][38] = '경남마산동부경찰서'
gicho_2018['police'][39] = '경남진해경찰서'
gicho_2018['police'][40] = '경기수원서부경찰서'
# Out:
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
gicho_2019['police'][3] = '충남세종경찰서'
gicho_2019['police'][6] = '경기수원중부경찰서'
gicho_2019['police'][12] = '경남진주경찰서'
gicho_2019['police'][15] = '경남창원서부경찰서'
gicho_2019['police'][31] = '경기수원남부경찰서'
gicho_2019['police'][33] = '경남창원중부경찰서'
gicho_2019['police'][37] = '경남마산중부경찰서'
gicho_2019['police'][38] = '경남마산동부경찰서'
gicho_2019['police'][39] = '경남진해경찰서'
gicho_2019['police'][40] = '경기수원서부경찰서'
# Out:
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
gicho_2020['police'][3] = '충남세종경찰서'
gicho_2020['police'][6] = '경기수원중부경찰서'
gicho_2020['police'][12] = '경남진주경찰서'
gicho_2020['police'][15] = '경남창원서부경찰서'
gicho_2020['police'][31] = '경기수원남부경찰서'
gicho_2020['police'][33] = '경남창원중부경찰서'
gicho_2020['police'][37] = '경남마산중부경찰서'
gicho_2020['police'][38] = '경남마산동부경찰서'
gicho_2020['police'][39] = '경남진해경찰서'
gicho_2020['police'][40] = '경기수원서부경찰서'
# Out:
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
gicho_2017 = gicho_2017.sort_values(by = ['police'])
gicho_2018 = gicho_2018.sort_values(by = ['police'])
gicho_2019 = gicho_2019.sort_values(by = ['police'])
gicho_2020 = gicho_2020.sort_values(by = ['police'])

# %%
gicho_2017
# Out:
#        police  19세 이하  20 ~ 34세  35 ~ 59세  60세 이상  year
# 31  경기수원남부경찰서   39101      9131     40639   50273  2017
# 40  경기수원서부경찰서   39101      9131     40639   50273  2017
# 6   경기수원중부경찰서   39101      9131     40639   50273  2017
# 38  경남마산동부경찰서   54889     11055     56994   66509  2017
# 37  경남마산중부경찰서   54889     11055     56994   66509  2017
# 12    경남진주경찰서   27844      6520     29128   28780  2017
# 39    경남진해경찰서   54889     11055     56994   66509  2017
# 15  경남창원서부경찰서   54889     11055     56994   66509  2017
# 33  경남창원중부경찰서   54889     11055     56994   66509  2017
# 36    서울강남경찰서   17789      8699     25298   33903  2017
# 11    서울강동경찰서   19558      5976     23078   25727  2017
# 9     서울강북경찰서   29508      9281     35737   43051  2017
# 1     서울강서경찰서   31758     14649     51392   65237  2017
# 8     서울관악경찰서   21840      9395     31669   38508  2017
# 10    서울광진경찰서   18260      4472     17579   18554  2017
# 24    서울구로경찰서   16732      4593     17586   25170  2017
# ...

# %%
df = pd.concat([gicho_2017, gicho_2018, gicho_2019, gicho_2020], axis = 0)

# %%
df = df[['police', 'year', '19세 이하','20 ~ 34세','35 ~ 59세', '60세 이상']]

# %%
df = df.reset_index(drop=True)

# %%
df['총합'] = None

# %%
for i in range(len(df)):
    df['총합'][i] = df['19세 이하'][i] + df['20 ~ 34세'][i] + df['35 ~ 59세'][i] + df['60세 이상'][i]
# Out:
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#         police  year  19세 이하  20 ~ 34세  35 ~ 59세  60세 이상      총합
# 0    경기수원남부경찰서  2017   39101      9131     40639   50273  139144
# 1    경기수원서부경찰서  2017   39101      9131     40639   50273  139144
# 2    경기수원중부경찰서  2017   39101      9131     40639   50273  139144
# 3    경남마산동부경찰서  2017   54889     11055     56994   66509  189447
# 4    경남마산중부경찰서  2017   54889     11055     56994   66509  189447
# ..         ...   ...     ...       ...       ...     ...     ...
# 159    서울종암경찰서  2020   31361     11882     43894   69254  156391
# 160    서울중랑경찰서  2020   46485     15246     64943   92574  219248
# 161    서울중부경찰서  2020    6833      2472     14862   28268   52435
# 162    서울혜화경찰서  2020    5756      2573     14071   25508   47908
# 163    충남세종경찰서  2020   16060      4101     15794   22678   58633
#
# [164 rows x 7 columns]

# %%
df.to_csv('기초수급자현황.csv')
