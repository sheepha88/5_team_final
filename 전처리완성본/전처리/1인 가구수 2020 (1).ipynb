# %%
import numpy as np
import pandas as pd

# %%
## 하나의 구에 두개의 관할서가 있는 경우

## 강남구
## 수서경찰서
seoul_gagu_suseo = pd.read_csv('../finalproject/KOSIS/seoul_gagu/suseo.csv', encoding='cp949')
seoul_gagu_suseo = seoul_gagu_suseo.rename(columns=seoul_gagu_suseo.iloc[0])
seoul_gagu_suseo = seoul_gagu_suseo.drop(seoul_gagu_suseo.index[0])
seoul_gagu_suseo = seoul_gagu_suseo.iloc[:,4].astype(int).sum()

## 강남경찰서
seoul_gagu_gangnam = pd.read_csv('../finalproject/KOSIS/seoul_gagu/gangnam.csv', encoding='cp949')
seoul_gagu_gangnam = seoul_gagu_gangnam.rename(columns=seoul_gagu_gangnam.iloc[0])
seoul_gagu_gangnam = seoul_gagu_gangnam.drop(seoul_gagu_gangnam.index[0])
seoul_gagu_gangnam = seoul_gagu_gangnam.iloc[:,4].astype(int).sum()


## 종로구
## 종로경찰서
seoul_gagu_jongro = pd.read_csv('../finalproject/KOSIS/seoul_gagu/jongro.csv', encoding='cp949')
seoul_gagu_jongro = seoul_gagu_jongro.rename(columns=seoul_gagu_jongro.iloc[0])
seoul_gagu_jongro = seoul_gagu_jongro.drop(seoul_gagu_jongro.index[0])
seoul_gagu_jongro = seoul_gagu_jongro.iloc[:,4].astype(int).sum()


## 혜화경찰서
seoul_gagu_hyehwa = pd.read_csv('../finalproject/KOSIS/seoul_gagu/hyehwa.csv', encoding='cp949')
seoul_gagu_hyehwa = seoul_gagu_hyehwa.rename(columns=seoul_gagu_hyehwa.iloc[0])
seoul_gagu_hyehwa = seoul_gagu_hyehwa.drop(seoul_gagu_hyehwa.index[0])
seoul_gagu_hyehwa = seoul_gagu_hyehwa.iloc[:,4].astype(int).sum()


## 중구
## 남대문경찰서
seoul_gagu_namdaemun = pd.read_csv('../finalproject/KOSIS/seoul_gagu/namdaemun.csv', encoding='cp949')
seoul_gagu_namdaemun = seoul_gagu_namdaemun.rename(columns=seoul_gagu_namdaemun.iloc[0])
seoul_gagu_namdaemun = seoul_gagu_namdaemun.drop(seoul_gagu_namdaemun.index[0])
seoul_gagu_namdaemun = seoul_gagu_namdaemun.iloc[:,4].astype(int).sum()


## 중부경찰서
seoul_gagu_jungbu = pd.read_csv('../finalproject/KOSIS/seoul_gagu/jungbu.csv', encoding='cp949')
seoul_gagu_jungbu = seoul_gagu_jungbu.rename(columns=seoul_gagu_jungbu.iloc[0])
seoul_gagu_jungbu = seoul_gagu_jungbu.drop(seoul_gagu_jungbu.index[0])
seoul_gagu_jungbu = seoul_gagu_jungbu.iloc[:,4].astype(int).sum()


## 서초구
## 방배경찰서
seoul_gagu_bangbae = pd.read_csv('../finalproject/KOSIS/seoul_gagu/bangbae.csv', encoding='cp949')
seoul_gagu_bangbae = seoul_gagu_bangbae.rename(columns=seoul_gagu_bangbae.iloc[0])
seoul_gagu_bangbae = seoul_gagu_bangbae.drop(seoul_gagu_bangbae.index[0])
seoul_gagu_bangbae = seoul_gagu_bangbae.iloc[:,4].astype(int).sum()



## 서초경찰서
seoul_gagu_seocho = pd.read_csv('../finalproject/KOSIS/seoul_gagu/seocho.csv', encoding='cp949')
seoul_gagu_seocho = seoul_gagu_seocho.rename(columns=seoul_gagu_seocho.iloc[0])
seoul_gagu_seocho = seoul_gagu_seocho.drop(seoul_gagu_seocho.index[0])
seoul_gagu_seocho = seoul_gagu_seocho.iloc[:,4].astype(int).sum()



## 은평구
## 서부경찰서
seoul_gagu_seobu = pd.read_csv('../finalproject/KOSIS/seoul_gagu/seobu.csv', encoding='cp949')
seoul_gagu_seobu = seoul_gagu_seobu.rename(columns=seoul_gagu_seobu.iloc[0])
seoul_gagu_seobu = seoul_gagu_seobu.drop(seoul_gagu_seobu.index[0])
seoul_gagu_seobu = seoul_gagu_seobu.iloc[:,4].astype(int).sum()



## 은평경찰서
seoul_gagu_eunpyeong = pd.read_csv('../finalproject/KOSIS/seoul_gagu/eunpyeong.csv', encoding='cp949')
seoul_gagu_eunpyeong = seoul_gagu_eunpyeong.rename(columns=seoul_gagu_eunpyeong.iloc[0])
seoul_gagu_eunpyeong = seoul_gagu_eunpyeong.drop(seoul_gagu_eunpyeong.index[0])
seoul_gagu_eunpyeong = seoul_gagu_eunpyeong.iloc[:,4].astype(int).sum()


## 성북구
## 성북경찰서
seoul_gagu_sungbuk = pd.read_csv('../finalproject/KOSIS/seoul_gagu/sungbuk.csv', encoding='cp949')
seoul_gagu_sungbuk = seoul_gagu_sungbuk.rename(columns=seoul_gagu_sungbuk.iloc[0])
seoul_gagu_sungbuk = seoul_gagu_sungbuk.drop(seoul_gagu_sungbuk.index[0])
seoul_gagu_sungbuk = seoul_gagu_sungbuk.iloc[:,4].astype(int).sum()


## 종암경찰서
seoul_gagu_jongam = pd.read_csv('../finalproject/KOSIS/seoul_gagu/jongam.csv', encoding='cp949')
seoul_gagu_jongam = seoul_gagu_jongam.rename(columns=seoul_gagu_jongam.iloc[0])
seoul_gagu_jongam = seoul_gagu_jongam.drop(seoul_gagu_jongam.index[0])
seoul_gagu_jongam = seoul_gagu_jongam.iloc[:,4].astype(int).sum()

# %%
## 그 외
## 도봉경찰서
seoul_gagu_dobong = pd.read_csv('../finalproject/KOSIS/seoul_gagu/dobong.csv', encoding='cp949')
seoul_gagu_dobong = seoul_gagu_dobong.rename(columns=seoul_gagu_dobong.iloc[0])
seoul_gagu_dobong = seoul_gagu_dobong.drop(seoul_gagu_dobong.index[0])
seoul_gagu_dobong = seoul_gagu_dobong.iloc[:,1].astype(int).sum()

## 동대문경찰서
seoul_gagu_dongdaemun = pd.read_csv('../finalproject/KOSIS/seoul_gagu/dongdaemun.csv', encoding='cp949')
seoul_gagu_dongdaemun = seoul_gagu_dongdaemun.rename(columns=seoul_gagu_dongdaemun.iloc[0])
seoul_gagu_dongdaemun = seoul_gagu_dongdaemun.drop(seoul_gagu_dongdaemun.index[0])
seoul_gagu_dongdaemun = seoul_gagu_dongdaemun.iloc[:,1].astype(int).sum()

## 동작경찰서
seoul_gagu_dongjak = pd.read_csv('../finalproject/KOSIS/seoul_gagu/dongjak.csv', encoding='cp949')
seoul_gagu_dongjak = seoul_gagu_dongjak.rename(columns=seoul_gagu_dongjak.iloc[0])
seoul_gagu_dongjak = seoul_gagu_dongjak.drop(seoul_gagu_dongjak.index[0])
seoul_gagu_dongjak = seoul_gagu_dongjak.iloc[:,1].astype(int).sum()

## 강북경찰서
seoul_gagu_gangbuk = pd.read_csv('../finalproject/KOSIS/seoul_gagu/gangbuk.csv', encoding='cp949')
seoul_gagu_gangbuk = seoul_gagu_gangbuk.rename(columns=seoul_gagu_gangbuk.iloc[0])
seoul_gagu_gangbuk = seoul_gagu_gangbuk.drop(seoul_gagu_gangbuk.index[0])
seoul_gagu_gangbuk = seoul_gagu_gangbuk.iloc[:,1].astype(int).sum()

## 강동경찰서
seoul_gagu_gangdong = pd.read_csv('../finalproject/KOSIS/seoul_gagu/gangdong.csv', encoding='cp949')
seoul_gagu_gangdong = seoul_gagu_gangdong.rename(columns=seoul_gagu_gangdong.iloc[0])
seoul_gagu_gangdong = seoul_gagu_gangdong.drop(seoul_gagu_gangdong.index[0])
seoul_gagu_gangdong = seoul_gagu_gangdong.iloc[:,1].astype(int).sum()

## 강서경찰서
seoul_gagu_gangseo = pd.read_csv('../finalproject/KOSIS/seoul_gagu/gangseo.csv', encoding='cp949')
seoul_gagu_gangseo = seoul_gagu_gangseo.rename(columns=seoul_gagu_gangseo.iloc[0])
seoul_gagu_gangseo = seoul_gagu_gangseo.drop(seoul_gagu_gangseo.index[0])
seoul_gagu_gangseo = seoul_gagu_gangseo.iloc[:,1].astype(int).sum()

## 금천경찰서
seoul_gagu_geumchun = pd.read_csv('../finalproject/KOSIS/seoul_gagu/geumchun.csv', encoding='cp949')
seoul_gagu_geumchun = seoul_gagu_geumchun.rename(columns=seoul_gagu_geumchun.iloc[0])
seoul_gagu_geumchun = seoul_gagu_geumchun.drop(seoul_gagu_geumchun.index[0])
seoul_gagu_geumchun = seoul_gagu_geumchun.iloc[:,1].astype(int).sum()

## 구로경찰서
seoul_gagu_guro = pd.read_csv('../finalproject/KOSIS/seoul_gagu/guro.csv', encoding='cp949')
seoul_gagu_guro = seoul_gagu_guro.rename(columns=seoul_gagu_guro.iloc[0])
seoul_gagu_guro = seoul_gagu_guro.drop(seoul_gagu_guro.index[0])
seoul_gagu_guro = seoul_gagu_guro.iloc[:,1].astype(int).sum()

## 관악경찰서
seoul_gagu_gwanak = pd.read_csv('../finalproject/KOSIS/seoul_gagu/gwanak.csv', encoding='cp949')
seoul_gagu_gwanak = seoul_gagu_gwanak.rename(columns=seoul_gagu_gwanak.iloc[0])
seoul_gagu_gwanak = seoul_gagu_gwanak.drop(seoul_gagu_gwanak.index[0])
seoul_gagu_gwanak = seoul_gagu_gwanak.iloc[:,1].astype(int).sum()

## 광진경찰서
seoul_gagu_gwangjin = pd.read_csv('../finalproject/KOSIS/seoul_gagu/gwangjin.csv', encoding='cp949')
seoul_gagu_gwangjin = seoul_gagu_gwangjin.rename(columns=seoul_gagu_gwangjin.iloc[0])
seoul_gagu_gwangjin = seoul_gagu_gwangjin.drop(seoul_gagu_gwangjin.index[0])
seoul_gagu_gwangjin = seoul_gagu_gwangjin.iloc[:,1].astype(int).sum()

## 중랑경찰서
seoul_gagu_jungrang = pd.read_csv('../finalproject/KOSIS/seoul_gagu/jungrang.csv', encoding='cp949')
seoul_gagu_jungrang = seoul_gagu_jungrang.rename(columns=seoul_gagu_jungrang.iloc[0])
seoul_gagu_jungrang = seoul_gagu_jungrang.drop(seoul_gagu_jungrang.index[0])
seoul_gagu_jungrang = seoul_gagu_jungrang.iloc[:,1].astype(int).sum()

## 마포경찰서
seoul_gagu_mapo = pd.read_csv('../finalproject/KOSIS/seoul_gagu/mapo.csv', encoding='cp949')
seoul_gagu_mapo = seoul_gagu_mapo.rename(columns=seoul_gagu_mapo.iloc[0])
seoul_gagu_mapo = seoul_gagu_mapo.drop(seoul_gagu_mapo.index[0])
seoul_gagu_mapo = seoul_gagu_mapo.iloc[:,1].astype(int).sum()

## 노원경찰서
seoul_gagu_nowon = pd.read_csv('../finalproject/KOSIS/seoul_gagu/nowon.csv', encoding='cp949')
seoul_gagu_nowon = seoul_gagu_nowon.rename(columns=seoul_gagu_nowon.iloc[0])
seoul_gagu_nowon = seoul_gagu_nowon.drop(seoul_gagu_nowon.index[0])
seoul_gagu_nowon = seoul_gagu_nowon.iloc[:,1].astype(int).sum()

## 서대문경찰서
seoul_gagu_seodaemun = pd.read_csv('../finalproject/KOSIS/seoul_gagu/seodaemun.csv', encoding='cp949')
seoul_gagu_seodaemun = seoul_gagu_seodaemun.rename(columns=seoul_gagu_seodaemun.iloc[0])
seoul_gagu_seodaemun = seoul_gagu_seodaemun.drop(seoul_gagu_seodaemun.index[0])
seoul_gagu_seodaemun = seoul_gagu_seodaemun.iloc[:,1].astype(int).sum()

## 송파경찰서
seoul_gagu_songpa = pd.read_csv('../finalproject/KOSIS/seoul_gagu/songpa.csv', encoding='cp949')
seoul_gagu_songpa = seoul_gagu_songpa.rename(columns=seoul_gagu_songpa.iloc[0])
seoul_gagu_songpa = seoul_gagu_songpa.drop(seoul_gagu_songpa.index[0])
seoul_gagu_songpa = seoul_gagu_songpa.iloc[:,1].astype(int).sum()

## 성동경찰서
seoul_gagu_sungdong = pd.read_csv('../finalproject/KOSIS/seoul_gagu/sungdong.csv', encoding='cp949')
seoul_gagu_sungdong = seoul_gagu_sungdong.rename(columns=seoul_gagu_sungdong.iloc[0])
seoul_gagu_sungdong = seoul_gagu_sungdong.drop(seoul_gagu_sungdong.index[0])
seoul_gagu_sungdong = seoul_gagu_sungdong.iloc[:,1].astype(int).sum()

## 양천경찰서
seoul_gagu_yangchun = pd.read_csv('../finalproject/KOSIS/seoul_gagu/yangchun.csv', encoding='cp949')
seoul_gagu_yangchun = seoul_gagu_yangchun.rename(columns=seoul_gagu_yangchun.iloc[0])
seoul_gagu_yangchun = seoul_gagu_yangchun.drop(seoul_gagu_yangchun.index[0])
seoul_gagu_yangchun = seoul_gagu_yangchun.iloc[:,1].astype(int).sum()

## 용산경찰서
seoul_gagu_yongsan = pd.read_csv('../finalproject/KOSIS/seoul_gagu/yongsan.csv', encoding='cp949')
seoul_gagu_yongsan = seoul_gagu_yongsan.rename(columns=seoul_gagu_yongsan.iloc[0])
seoul_gagu_yongsan = seoul_gagu_yongsan.drop(seoul_gagu_yongsan.index[0])
seoul_gagu_yongsan = seoul_gagu_yongsan.iloc[:,1].astype(int).sum()

## 영등포경찰서
seoul_gagu_yungdeungpo = pd.read_csv('../finalproject/KOSIS/seoul_gagu/yungdeungpo.csv', encoding='cp949')
seoul_gagu_yungdeungpo = seoul_gagu_yungdeungpo.rename(columns=seoul_gagu_yungdeungpo.iloc[0])
seoul_gagu_yungdeungpo = seoul_gagu_yungdeungpo.drop(seoul_gagu_yungdeungpo.index[0])
seoul_gagu_yungdeungpo = seoul_gagu_yungdeungpo.iloc[:,1].astype(int).sum()

# %%
## 수원

suwon_gagu_jungbu = pd.read_csv('../finalproject/KOSIS/suwon_gagu/jungbu.csv', encoding='cp949')
suwon_gagu_jungbu = suwon_gagu_jungbu.rename(columns=suwon_gagu_jungbu.iloc[0])
suwon_gagu_jungbu = suwon_gagu_jungbu.drop(suwon_gagu_jungbu.index[0])
suwon_gagu_jungbu = suwon_gagu_jungbu.iloc[:,4].astype(int).sum()

suwon_gagu_seobu = pd.read_csv('../finalproject/KOSIS/suwon_gagu/seobu.csv', encoding='cp949')
suwon_gagu_seobu = suwon_gagu_seobu.replace('-',0)
suwon_gagu_seobu = suwon_gagu_seobu.rename(columns=suwon_gagu_seobu.iloc[0])
suwon_gagu_seobu = suwon_gagu_seobu.drop(suwon_gagu_seobu.index[0])
suwon_gagu_seobu = suwon_gagu_seobu.iloc[:,4].astype(int).sum()

suwon_gagu_nambu = pd.read_csv('../finalproject/KOSIS/suwon_gagu/nambu.csv', encoding='cp949')
suwon_gagu_nambu = suwon_gagu_nambu.replace('-',0)
suwon_gagu_nambu = suwon_gagu_nambu.rename(columns=suwon_gagu_nambu.iloc[0])
suwon_gagu_nambu = suwon_gagu_nambu.drop(suwon_gagu_nambu.index[0])
suwon_gagu_nambu = suwon_gagu_nambu.iloc[:,4].astype(int).sum()

# %%
## 창원

masan_gagu_dongbu = pd.read_csv('../finalproject/KOSIS/changwon_gagu/masan_dongbu.csv', encoding='cp949')
masan_gagu_dongbu = masan_gagu_dongbu.replace('-',0)
masan_gagu_dongbu = masan_gagu_dongbu.rename(columns=masan_gagu_dongbu.iloc[0])
masan_gagu_dongbu = masan_gagu_dongbu.drop(masan_gagu_dongbu.index[0])
masan_gagu_dongbu = masan_gagu_dongbu.iloc[:,1].astype(int).sum()

masan_gagu_jungbu = pd.read_csv('../finalproject/KOSIS/changwon_gagu/masan_jungbu.csv', encoding='cp949')
masan_gagu_jungbu = masan_gagu_jungbu.replace('-',0)
masan_gagu_jungbu = masan_gagu_jungbu.rename(columns=masan_gagu_jungbu.iloc[0])
masan_gagu_jungbu = masan_gagu_jungbu.drop(masan_gagu_jungbu.index[0])
masan_gagu_jungbu = masan_gagu_jungbu.iloc[:,1].astype(int).sum()

changwon_gagu_seobu = pd.read_csv('../finalproject/KOSIS/changwon_gagu/seobu.csv', encoding='cp949')
changwon_gagu_seobu = changwon_gagu_seobu.replace('-',0)
changwon_gagu_seobu = changwon_gagu_seobu.rename(columns=changwon_gagu_seobu.iloc[0])
changwon_gagu_seobu = changwon_gagu_seobu.drop(changwon_gagu_seobu.index[0])
changwon_gagu_seobu = changwon_gagu_seobu.iloc[:,4].astype(int).sum()

changwon_gagu_jungbu = pd.read_csv('../finalproject/KOSIS/changwon_gagu/jungbu.csv', encoding='cp949')
changwon_gagu_jungbu = changwon_gagu_jungbu.replace('-',0)
changwon_gagu_jungbu = changwon_gagu_jungbu.rename(columns=changwon_gagu_jungbu.iloc[0])
changwon_gagu_jungbu = changwon_gagu_jungbu.drop(changwon_gagu_jungbu.index[0])
changwon_gagu_jungbu = changwon_gagu_jungbu.iloc[:,4].astype(int).sum()

jinhae_gagu = pd.read_csv('../finalproject/KOSIS/changwon_gagu/jinhae.csv', encoding='cp949')
jinhae_gagu = jinhae_gagu.replace('-',0)
jinhae_gagu = jinhae_gagu.rename(columns=jinhae_gagu.iloc[0])
jinhae_gagu = jinhae_gagu.drop(jinhae_gagu.index[0])
jinhae_gagu = jinhae_gagu.iloc[:,1].astype(int).sum()

# %%
## 진해, 세종
jinju_gagu = pd.read_csv('../finalproject/KOSIS/changwon_gagu/jinju.csv', encoding='cp949')
jinju_gagu = jinju_gagu.replace('-',0)
jinju_gagu = jinju_gagu.rename(columns=jinju_gagu.iloc[0])
jinju_gagu = jinju_gagu.drop(jinju_gagu.index[0])
jinju_gagu = jinju_gagu.iloc[:,1].astype(int).sum()

sejong_gagu = pd.read_csv('../finalproject/KOSIS/changwon_gagu/sejong.csv', encoding='cp949')
sejong_gagu = sejong_gagu.replace('-',0)
sejong_gagu = sejong_gagu.rename(columns=sejong_gagu.iloc[0])
sejong_gagu = sejong_gagu.drop(sejong_gagu.index[0])
sejong_gagu = sejong_gagu.iloc[:,1].astype(int).sum()

# %%
solo_pop_2020 = pd.DataFrame({'jur_stn' : ['서울수서경찰서',
'서울강남경찰서',
'서울종로경찰서',
'서울혜화경찰서',
'서울남대문경찰서',
'서울중부경찰서',
'서울방배경찰서',
'서울서초경찰서',
'서울서부경찰서',
'서울은평경찰서',
'서울성북경찰서',
'서울종암경찰서',
'서울강서경찰서',
'서울중랑경찰서',
'서울동작경찰서',
'서울강동경찰서',
'서울강북경찰서',
'서울관악경찰서',
'서울광진경찰서',
'서울구로경찰서',
'서울금천경찰서',
'서울노원경찰서',
'서울도봉경찰서',
'서울동대문경찰서',
'서울마포경찰서',
'서울서대문경찰서',
'서울성동경찰서',
'서울송파경찰서',
'서울양천경찰서',
'서울영등포경찰서',
'서울용산경찰서',
'경기수원중부경찰서',
'경기수원서부경찰서',
'경기수원남부경찰서',
'경남마산서부경찰서',
'경남마산중부경찰서',
'경남창원중부경찰서',
'경남창원서부경찰서',
'경남진해경찰서',
'경남진주경찰서',
'충남세종경찰서'],
'1인가구 수':
[seoul_gagu_suseo,
seoul_gagu_gangnam,
seoul_gagu_jongro,
seoul_gagu_hyehwa,
seoul_gagu_namdaemun,
seoul_gagu_jungbu,
seoul_gagu_bangbae,
seoul_gagu_seocho,
seoul_gagu_seobu,
seoul_gagu_eunpyeong,
seoul_gagu_sungbuk,
seoul_gagu_jongam,
seoul_gagu_gangseo,
seoul_gagu_jungrang,
seoul_gagu_dongjak,
seoul_gagu_gangdong,
seoul_gagu_gangbuk,
seoul_gagu_gwanak,
seoul_gagu_gwangjin,
seoul_gagu_guro,
seoul_gagu_geumchun,
seoul_gagu_nowon,
seoul_gagu_dobong,
seoul_gagu_dongdaemun,
seoul_gagu_mapo,
seoul_gagu_seodaemun,
seoul_gagu_sungdong,
seoul_gagu_songpa,
seoul_gagu_yangchun,
seoul_gagu_yungdeungpo,
seoul_gagu_yongsan,
suwon_gagu_jungbu,
suwon_gagu_seobu,
suwon_gagu_nambu,
masan_gagu_dongbu,
masan_gagu_jungbu,
changwon_gagu_jungbu,
changwon_gagu_seobu,
jinhae_gagu,
jinju_gagu,
sejong_gagu]})

# %%
solo_pop_2020.to_csv('C:/hnooee/pythonwork/finalproject/총 1인가구 수 2020.csv',encoding='UTF-8')
