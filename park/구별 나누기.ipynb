# %%
import numpy as np
import pandas as pd
import math

# %% [markdown]
# ### 1) 교통사고 현황

# %%
df_acc = pd.read_csv('11.5개시도_교통사고현황.csv')

# %%
df_acc
# Out:
#              date      acc_case ofn_sx ofn_age vic_sx vic_age jur_stn
# 0        2018년 1월    차대차 - 측면충돌      남     20대      남     50대    서울중부
# 1        2018년 1월    차대차 - 측면충돌      여     50대      남     70대    서울중부
# 2        2018년 1월    차대차 - 측면충돌      남     40대      남     50대    서울중부
# 3        2018년 1월      차대차 - 기타   기타불명     미분류      여     40대    서울중부
# 4        2018년 1월      차대차 - 기타      남     60대      남     50대    서울중부
# ...           ...           ...    ...     ...    ...     ...     ...
# 140949   2019년 8월    차대사람 - 횡단중      남     40대      여  90대 이상    마산중부
# 140950  2020년 12월  차대사람 - 차도통행중      여     40대      여  90대 이상    창원중부
# 140951   2019년 4월    차대사람 - 횡단중      남     60대      남  90대 이상   진해경찰서
# 140952   2019년 5월  차대사람 - 차도통행중      남     20대      남  90대 이상   진해경찰서
# 140953   2020년 9월      차대차 - 기타      여     40대      남  90대 이상   진해경찰서
#
# [140954 rows x 7 columns]

# %%
jungbu = df_acc[df_acc['jur_stn'] == '서울중부']
jongro = df_acc[df_acc['jur_stn'] == '서울종로']
namdae = df_acc[df_acc['jur_stn'] == '서울남대문']
seodae = df_acc[df_acc['jur_stn'] == '서울서대문']
hyewha = df_acc[df_acc['jur_stn'] == '서울혜화']
yongsan = df_acc[df_acc['jur_stn'] == '서울용산']
soungbuk = df_acc[df_acc['jur_stn'] == '서울성북']
dongdae = df_acc[df_acc['jur_stn'] == '서울동대문']

# %%
#### 8개 관할서 교통사고 횟수 
jungbu.reset_index(drop=True, inplace = True)
jongro.reset_index(drop=True, inplace = True)
namdae.reset_index(drop=True, inplace = True)
seodae.reset_index(drop=True, inplace = True)
hyewha.reset_index(drop=True, inplace = True)
yongsan.reset_index(drop=True, inplace = True)
soungbuk.reset_index(drop=True, inplace = True)
dongdae.reset_index(drop=True, inplace = True)

# %%
len(jungbu)
# Out:
# 1716

# %%
jungbu
# Out:
#            date      acc_case ofn_sx ofn_age vic_sx vic_age jur_stn
# 0      2018년 1월    차대차 - 측면충돌      남     20대      남     50대    서울중부
# 1      2018년 1월    차대차 - 측면충돌      여     50대      남     70대    서울중부
# 2      2018년 1월    차대차 - 측면충돌      남     40대      남     50대    서울중부
# 3      2018년 1월      차대차 - 기타   기타불명     미분류      여     40대    서울중부
# 4      2018년 1월      차대차 - 기타      남     60대      남     50대    서울중부
# ...         ...           ...    ...     ...    ...     ...     ...
# 1711   2018년 7월  차대사람 - 차도통행중      남     40대      여  90대 이상    서울중부
# 1712   2019년 6월     차대사람 - 기타      여     40대      여  90대 이상    서울중부
# 1713   2019년 6월    차대사람 - 횡단중      남     60대      남  90대 이상    서울중부
# 1714  2019년 12월    차대사람 - 횡단중      남     20대      남  90대 이상    서울중부
# 1715   2020년 8월     차대사람 - 기타      남     30대      여  90대 이상    서울중부
#
# [1716 rows x 7 columns]

# %%
df_acc[df_acc['jur_stn'] == '서울중부']
# Out:
#              date      acc_case ofn_sx ofn_age vic_sx vic_age jur_stn
# 0        2018년 1월    차대차 - 측면충돌      남     20대      남     50대    서울중부
# 1        2018년 1월    차대차 - 측면충돌      여     50대      남     70대    서울중부
# 2        2018년 1월    차대차 - 측면충돌      남     40대      남     50대    서울중부
# 3        2018년 1월      차대차 - 기타   기타불명     미분류      여     40대    서울중부
# 4        2018년 1월      차대차 - 기타      남     60대      남     50대    서울중부
# ...           ...           ...    ...     ...    ...     ...     ...
# 140851   2018년 7월  차대사람 - 차도통행중      남     40대      여  90대 이상    서울중부
# 140852   2019년 6월     차대사람 - 기타      여     40대      여  90대 이상    서울중부
# 140853   2019년 6월    차대사람 - 횡단중      남     60대      남  90대 이상    서울중부
# 140854  2019년 12월    차대사람 - 횡단중      남     20대      남  90대 이상    서울중부
# 140926   2020년 8월     차대사람 - 기타      남     30대      여  90대 이상    서울중부
#
# [1716 rows x 7 columns]

# %%
jongro.groupby(['jur_stn', 'date', 'acc_case']).size()
# Out:
# jur_stn  date       acc_case
# 서울종로     2018년 10월  차대사람 - 기타             2
#                     차대사람 - 길가장자리구역통행중     1
#                     차대사람 - 보도통행중          2
#                     차대사람 - 차도통행중          3
#                     차대사람 - 횡단중            9
#                                          ..
#          2020년 9월   차대차  - 정면충돌           2
#                     차대차  - 추돌            10
#                     차대차  - 측면충돌          12
#                     차대차  - 후진중충돌          2
#                     차량단독  - 기타            1
# Length: 324, dtype: int64

# %% [markdown]
# ### 2) 화재 현황

# %%
df_fire = pd.read_csv('13.5개시도_화재발생통계.csv')

# %%
df_fire = df_fire[df_fire['sido'] == '서울특별시']

# %%
df_fire.reset_index(drop=True, inplace=True)

# %%
df_fire.drop(['sido'], axis = 1, inplace=True)

# %%
df_fire.head()
# Out:
#      yr sgg_nm  acc_num  dead_num  injr_num  tot_vic_num  prop_dmg  \
# 0  2018    강남구      436         0        23           23    670429
# 1  2018    강동구      324         4        15           19    236181
# 2  2018    강북구      203         4         2            6    104658
# 3  2018    강서구      383         2        18           20    196115
# 4  2018    관악구      337         1        20           21    395475
#
#    chattel_dmg  assts_dmg  dmg_per_acc
# 0       954554    1624983         3727
# 1       304444     540625         1669
# 2       112180     216838         1068
# 3       197286     393401         1027
# 4       421087     816562         2423

# %%
pd.options.display.max_rows = 300

df_fire.groupby(['sgg_nm', 'yr', 'acc_num']).mean()
# Out:
#                      dead_num  injr_num  tot_vic_num  prop_dmg  chattel_dmg  \
# sgg_nm yr   acc_num
# 강남구    2018 436             0        23           23    670429       954554
#        2019 456             1        23           24    900260       777421
#        2020 387             1        18           19    923684       527872
# 강동구    2018 324             4        15           19    236181       304444
#        2019 254             1        10           11    166909       366450
#        2020 221             3        19           22    155078       208761
# 강북구    2018 203             4         2            6    104658       112180
#        2019 167             1         9           10     76389       141416
#        2020 186             1         5            6     99841       108539
# 강서구    2018 383             2        18           20    196115       197286
#        2019 331             0        24           24    251606       414691
# ...

# %% [markdown]
# ### 3) 1인가구수

# %%
df_one = pd.read_csv('15.5개시도_1인가구수.csv')

# %%
df_one = df_one[df_one['sido'] == '서울특별시']

# %%
df_one.drop(['sido'], axis = 1, inplace=True)

# %%
df_one.head()
# Out:
#   sgg_nm sx    age  date  resi_style  house_total_num  detached_house  \
# 0    종로구  계     합계  2017     23638.0            19260           11234
# 1    종로구  계  20세미만  2017       507.0              459             379
# 2    종로구  계  20~24  2017      2992.0             2519            1773
# 3    종로구  계  25~29  2017      3627.0             2845            1677
# 4    종로구  계  30~34  2017      2552.0             1970            1024
#
#   apartment townhouse multiplex_house house_in_commercial not_in_house  \
# 0      2992       887            3279                 868         4378
# 1        11        11              38                  20           48
# 2       158        44             340                 204          473
# 3       398        77             552                 141          782
# 4       357        64             449                  76          582
#
#    single_person_hh not_in_house_num
# 0               NaN              NaN
# 1               NaN              NaN
# ...

# %%
pd.options.display.max_rows = 5000
df_one.groupby(['sgg_nm', 'date', 'sx', 'age']).mean()
# Out:
#                          resi_style  house_total_num  detached_house  \
# sgg_nm date sx age
# 강남구    2017 계  20~24    3277.000000      2675.000000     1355.000000
#                20세미만     539.000000       349.000000      146.000000
#                25~29    9692.000000      7997.000000     3945.000000
#                30~34   11378.000000      9521.000000     4069.000000
#                35~39    8980.000000      7627.000000     2896.000000
#                40~44    5878.000000      4994.000000     1730.000000
#                45~49    4856.000000      4078.000000     1320.000000
#                50~54    3331.000000      2779.000000      893.000000
#                55~59    3248.000000      2790.000000      846.000000
#                60~64    3093.000000      2778.000000      621.000000
#                65~69    2646.000000      2396.000000      456.000000
#                70~74    2174.000000      2007.000000      368.000000
# ...

# %% [markdown]
# ### 4) 기초수급자

# %%
df_gicho = pd.read_csv('17.5개시도_기초수급자현황.csv')

# %%
df_gicho = df_gicho[df_gicho['sido'] == '서울특별시']

# %%
df_gicho.groupby(['sgg_nm', 'date']).size()
# Out:
# sgg_nm  date
# 강남구     201706    208
#         201707    104
#         201708    104
#         201709    104
#         201710    103
#         201711    103
#         201712    103
#         201801    103
#         201802    104
#         201803    104
#         201804    104
#         201805    103
#         201806    103
#         201807    103
#         201808    102
#         201809    102
#         201810    102
#         201811    102
#         201812    102
#         201901    102
#         201902    103
#         201903    103
#         201904    103
#         201905    103
#         201906    103
#         201907    104
#         201908    104
#         201909    104
#         201910    104
#         201911    104
#         201912    105
#         202001    105
#         202002    104
#         202003    105
#         202004    105
#         202005    105
#         202006    105
#         202007    105
#         202008    105
#         202009    105
#         202010    105
# ...

# %%
df_gicho.head()
# Out:
#      date   sido sgg_nm  age  num
# 0  201706  서울특별시    종로구    4    4
# 1  201706  서울특별시    종로구   45   26
# 2  201706  서울특별시    종로구   46   55
# 3  201706  서울특별시    종로구   47   37
# 4  201706  서울특별시    종로구   48   51

# %% [markdown]
# ### 4) 자살

# %%
df_suicide = pd.read_csv('18.5개시도_자살율.csv')

# %%
df_suicide
# Out:
#        sido sgg_nm  sx  dead_num_2017  dptt_2017  age_stndrd_dptt_2017  \
# 0     서울특별시    종로구  남자             33       45.3                  37.2
# 1     서울특별시    종로구  여자             12       15.9                  12.4
# 2     서울특별시     중구  남자             20       33.4                  26.0
# 3     서울특별시     중구  여자              7       11.5                   6.4
# 4     서울특별시    용산구  남자             36       33.7                  29.8
# 5     서울특별시    용산구  여자             16       14.2                  12.8
# 6     서울특별시    성동구  남자             50       34.1                  28.4
# 7     서울특별시    성동구  여자             17       11.3                   8.5
# 8     서울특별시    광진구  남자             54       31.4                  28.0
# 9     서울특별시    광진구  여자             17        9.4                   9.5
# 10    서울특별시   동대문구  남자             55       31.8                  26.7
# 11    서울특별시   동대문구  여자              9        5.2                   4.1
# ...

# %%
df_suicide = df_suicide[df_suicide['sido'] == '서울특별시']

# %%
df_suicide
# Out:
#      sido sgg_nm  sx  dead_num_2017  dptt_2017  age_stndrd_dptt_2017  \
# 0   서울특별시    종로구  남자             33       45.3                  37.2
# 1   서울특별시    종로구  여자             12       15.9                  12.4
# 2   서울특별시     중구  남자             20       33.4                  26.0
# 3   서울특별시     중구  여자              7       11.5                   6.4
# 4   서울특별시    용산구  남자             36       33.7                  29.8
# 5   서울특별시    용산구  여자             16       14.2                  12.8
# 6   서울특별시    성동구  남자             50       34.1                  28.4
# 7   서울특별시    성동구  여자             17       11.3                   8.5
# 8   서울특별시    광진구  남자             54       31.4                  28.0
# 9   서울특별시    광진구  여자             17        9.4                   9.5
# 10  서울특별시   동대문구  남자             55       31.8                  26.7
# 11  서울특별시   동대문구  여자              9        5.2                   4.1
# 12  서울특별시    중랑구  남자             74       36.8                  30.9
# ...

# %%
df_study = pd.read_csv('19.5개시도_최종학력통계.csv')

# %%
df_study = df_study[df_study['sido'] == '서울특별시']

# %%
df_study
# Out:
#         sido sgg_nm emd_nm  sx     age         inv_edu inv_detail  num_in_2015
# 0      서울특별시    종로구    사직동  남자      합계               계  6세 이상 내국인       3669.0
# 1      서울특별시    종로구    사직동  남자      합계            초등학교  6세 이상 내국인        339.0
# 2      서울특별시    종로구    사직동  남자      합계             중학교  6세 이상 내국인        237.0
# 3      서울특별시    종로구    사직동  남자      합계            고등학교  6세 이상 내국인        629.0
# 4      서울특별시    종로구    사직동  남자      합계      대학교(2,3년제)  6세 이상 내국인        196.0
# ...      ...    ...    ...  ..     ...             ...        ...          ...
# 78611  서울특별시    관악구    중앙동  여자  70세 이상            고등학교  6세 이상 내국인         73.0
# 78612  서울특별시    관악구    중앙동  여자  70세 이상      대학교(2,3년제)  6세 이상 내국인          4.0
# 78613  서울특별시    관악구    중앙동  여자  70세 이상     대학교(4년제 이상)  6세 이상 내국인          5.0
# 78614  서울특별시    관악구    중앙동  여자  70세 이상     대학원(석박사 과정)  6세 이상 내국인          NaN
# 78615  서울특별시    관악구    중앙동  여자  70세 이상  받지 않았음(미취학 포함)  6세 이상 내국인         39.0
#
# ...

# %%
df_fire
# Out:
#       yr sgg_nm  acc_num  dead_num  injr_num  tot_vic_num  prop_dmg  \
# 0   2018    강남구      436         0        23           23    670429
# 1   2018    강동구      324         4        15           19    236181
# 2   2018    강북구      203         4         2            6    104658
# 3   2018    강서구      383         2        18           20    196115
# 4   2018    관악구      337         1        20           21    395475
# 5   2018    광진구      203         0         7            7    315690
# 6   2018    구로구      263         2         3            5     74308
# 7   2018    금천구      168         0         8            8     55351
# 8   2018    노원구      229         2        10           12    105994
# 9   2018    도봉구      237         0         8            8     85113
# 10  2018   동대문구      203         1         3            4    179873
# 11  2018    동작구      205         4         9           13    103520
# 12  2018    마포구      254         2         4            6    132459
# ...

# %%
df_fire_2018 = df_fire[df_fire['yr'] == 2018]

# %%
fire_2018 = [df_fire_2018[df_fire_2018['sgg_nm'] == '종로구']['acc_num'].iloc[0], df_fire_2018[df_fire_2018['sgg_nm'] == '성북구']['acc_num'].iloc[0],
             df_fire_2018[df_fire_2018['sgg_nm'] == '중구']['acc_num'].iloc[0], df_fire_2018[df_fire_2018['sgg_nm'] == '용산구']['acc_num'].iloc[0],
             df_fire_2018[df_fire_2018['sgg_nm'] == '서대문구']['acc_num'].iloc[0], df_fire_2018[df_fire_2018['sgg_nm'] == '동대문구']['acc_num'].iloc[0]]

# %%
df = pd.DataFrame({'화재발생_2018' : fire_2018}, index = ['종로구', '성북구', '중구', '용산구', '서대문구', '동대문구'])

# %%
df
# Out:
#       화재발생_2018
# 종로구         254
# 성북구         215
# 중구          275
# 용산구         211
# 서대문구        229
# 동대문구        203

# %%
df_fire_2019 = df_fire[df_fire['yr'] == 2019]

fire_2019 = [df_fire_2019[df_fire_2019['sgg_nm'] == '종로구']['acc_num'].iloc[0], df_fire_2019[df_fire_2019['sgg_nm'] == '성북구']['acc_num'].iloc[0],
             df_fire_2019[df_fire_2019['sgg_nm'] == '중구']['acc_num'].iloc[0], df_fire_2019[df_fire_2019['sgg_nm'] == '용산구']['acc_num'].iloc[0],
             df_fire_2019[df_fire_2019['sgg_nm'] == '서대문구']['acc_num'].iloc[0], df_fire_2019[df_fire_2019['sgg_nm'] == '동대문구']['acc_num'].iloc[0]]

# %%
df_list = ['종로구', '성북구', '중구', '용산구', '서대문구', '동대문구']

# %%
fire_2019_s = pd.Series(fire_2019, index=df_list)
fire_2019_s.name = '화재발생_2019'

# %%
df_fire_2020 = df_fire[df_fire['yr'] == 2020]

fire_2020 = [df_fire_2020[df_fire_2020['sgg_nm'] == '종로구']['acc_num'].iloc[0], df_fire_2020[df_fire_2020['sgg_nm'] == '성북구']['acc_num'].iloc[0],
             df_fire_2020[df_fire_2020['sgg_nm'] == '중구']['acc_num'].iloc[0], df_fire_2020[df_fire_2020['sgg_nm'] == '용산구']['acc_num'].iloc[0],
             df_fire_2020[df_fire_2020['sgg_nm'] == '서대문구']['acc_num'].iloc[0], df_fire_2020[df_fire_2020['sgg_nm'] == '동대문구']['acc_num'].iloc[0]]

# %%
fire_2020_s = pd.Series(fire_2020, index=df_list)
fire_2020_s.name = '화재발생_2020'

# %%
df
# Out:
#      Unnamed: 0  화재발생_2018  화재발생_2019  화재발생_2020  2017 1인가구_여자  2017 1인가구_남자  \
# 0           종로구      254.0      232.0      217.0       10247.0       10766.0
# 1           성북구      215.0      191.0      173.0       27285.0       27921.0
# 2            중구      275.0      213.0      185.0       48653.0       50780.0
# 3           용산구      211.0      238.0      192.0       16297.0       16556.0
# 4          서대문구      229.0      269.0      220.0       22180.0       22734.0
# 5          동대문구      203.0      195.0      152.0       22999.0       24068.0
# 동대문구        NaN        NaN        NaN        NaN           NaN           NaN
# 서대문구        NaN        NaN        NaN        NaN           NaN           NaN
# 성북구         NaN        NaN        NaN        NaN           NaN           NaN
# 용산구         NaN        NaN        NaN        NaN           NaN           NaN
# 종로구         NaN        NaN        NaN        NaN           NaN           NaN
# ...

# %%
one = df_one[df_one['age'] == '합계']

# %%
one_2017 = one[one['date'] == 2017]
one_2017_man = one_2017[one_2017['sx'] == '남자']
one_2017_woman = one_2017[one_2017['sx'] == '여자']

# %%
df_dict = {}
df_list = ['종로구', '성북구', '중구', '용산구', '서대문구', '동대문구']
for i in df_list:
    df_dict[i] = one_2017_man[one_2017_man['sgg_nm'] == i]['house_total_num'].sum()

# %%
one_man_2017 = pd.Series(df_dict)
one_man_2017.name = '2017 1인가구_남자'

# %%
df_dict = {}
df_list = ['종로구', '성북구', '중구', '용산구', '서대문구', '동대문구']
for i in df_list:
    df_dict[i] = one_2017_woman[one_2017_woman['sgg_nm'] == i]['house_total_num'].sum()

# %%
one_woman_2017 = pd.Series(df_dict)
one_woman_2017.name = '2017 1인가구_여자'

# %%
one_2018 = one[one['date'] == 2018]
one_2018_man = one_2018[one_2018['sx'] == '남자']
one_2018_woman = one_2018[one_2018['sx'] == '여자']

# %%
df_dict = {}
df_list = ['종로구', '성북구', '중구', '용산구', '서대문구', '동대문구']
for i in df_list:
    df_dict[i] = one_2018_man[one_2018_man['sgg_nm'] == i]['house_total_num'].sum()

# %%
one_man_2018 = pd.Series(df_dict)
one_man_2018.name = '2018 1인가구_남자'

# %%
df_dict = {}
df_list = ['종로구', '성북구', '중구', '용산구', '서대문구', '동대문구']
for i in df_list:
    df_dict[i] = one_2018_woman[one_2018_woman['sgg_nm'] == i]['house_total_num'].sum()

# %%
one_woman_2018 = pd.Series(df_dict)
one_woman_2018.name = '2018 1인가구_여자'

# %%
one_2019 = one[one['date'] == 2018]
one_2019_man = one_2019[one_2019['sx'] == '남자']
one_2019_woman = one_2019[one_2019['sx'] == '여자']

# %%
df_dict = {}
df_list = ['종로구', '성북구', '중구', '용산구', '서대문구', '동대문구']
for i in df_list:
    df_dict[i] = one_2019_man[one_2019_man['sgg_nm'] == i]['house_total_num'].sum()

# %%
one_man_2019 = pd.Series(df_dict)
one_man_2019.name = '2019 1인가구_남자'

# %%
df_dict = {}
df_list = ['종로구', '성북구', '중구', '용산구', '서대문구', '동대문구']
for i in df_list:
    df_dict[i] = one_2019_woman[one_2019_woman['sgg_nm'] == i]['house_total_num'].sum()

# %%
one_woman_2019 = pd.Series(df_dict)
one_woman_2019.name = '2019 1인가구_여자'
one_woman_2019
# Out:
# 종로구     10766
# 성북구     27921
# 중구      50780
# 용산구     16556
# 서대문구    22734
# 동대문구    24068
# Name: 2019 1인가구_여자, dtype: int64

# %%
df_suicide = df_suicide[df_suicide['sido'] == '서울특별시']
df_suicide
# Out:
#      sido sgg_nm  sx  dead_num_2017  dptt_2017  age_stndrd_dptt_2017  \
# 0   서울특별시    종로구  남자             33       45.3                  37.2
# 1   서울특별시    종로구  여자             12       15.9                  12.4
# 2   서울특별시     중구  남자             20       33.4                  26.0
# 3   서울특별시     중구  여자              7       11.5                   6.4
# 4   서울특별시    용산구  남자             36       33.7                  29.8
# 5   서울특별시    용산구  여자             16       14.2                  12.8
# 6   서울특별시    성동구  남자             50       34.1                  28.4
# 7   서울특별시    성동구  여자             17       11.3                   8.5
# 8   서울특별시    광진구  남자             54       31.4                  28.0
# 9   서울특별시    광진구  여자             17        9.4                   9.5
# 10  서울특별시   동대문구  남자             55       31.8                  26.7
# 11  서울특별시   동대문구  여자              9        5.2                   4.1
# 12  서울특별시    중랑구  남자             74       36.8                  30.9
# ...

# %%
# df_suicide.drop(['dptt_2017', 'age_stndrd_dptt_2017', 'dptt_2018', 'age_stndrd_dptt_2018', 'dptt_2019', 'age_stndrd_dptt_2019'], axis = 1, inplace = True)

# %%
suicide_man = df_suicide[df_suicide['sx'] == '남자']
suicide_woman = df_suicide[df_suicide['sx'] == '여자']
suicide_man
# Out:
#      sido sgg_nm  sx  dead_num_2017  dptt_2017  age_stndrd_dptt_2017  \
# 0   서울특별시    종로구  남자             33       45.3                  37.2
# 2   서울특별시     중구  남자             20       33.4                  26.0
# 4   서울특별시    용산구  남자             36       33.7                  29.8
# 6   서울특별시    성동구  남자             50       34.1                  28.4
# 8   서울특별시    광진구  남자             54       31.4                  28.0
# 10  서울특별시   동대문구  남자             55       31.8                  26.7
# 12  서울특별시    중랑구  남자             74       36.8                  30.9
# 14  서울특별시    성북구  남자             69       32.2                  27.9
# 16  서울특별시    강북구  남자             63       40.2                  32.1
# 18  서울특별시    도봉구  남자             69       41.1                  35.1
# 20  서울특별시    노원구  남자             89       33.0                  28.8
# 22  서울특별시    은평구  남자             72       30.8                  25.9
# 24  서울특별시   서대문구  남자             42       28.3                  23.4
# ...

# %%
df_dict = {}
df_dict1 = {}
df_list = ['종로구', '성북구', '중구', '용산구', '서대문구', '동대문구']
for i in df_list:
    df_dict[i] = suicide_man[suicide_man['sgg_nm'] == i].iloc[:, 3].sum()
    df_dict1[i] = suicide_woman[suicide_woman['sgg_nm'] == i].iloc[:, 3].sum()

# %%
suicide_man_s_2017 = pd.Series(df_dict)
suicide_woman_s_2017 = pd.Series(df_dict1)
suicide_man_s_2017.name = '남자 자살_2017'
suicide_woman_s_2017.name = '여자 자살_2017'

# %%
df_dict = {}
df_dict1 = {}
df_list = ['종로구', '성북구', '중구', '용산구', '서대문구', '동대문구']
for i in df_list:
    df_dict[i] = suicide_man[suicide_man['sgg_nm'] == i].iloc[:, 4].sum()
    df_dict1[i] = suicide_woman[suicide_woman['sgg_nm'] == i].iloc[:, 4].sum()

# %%
suicide_man_s_2018 = pd.Series(df_dict)
suicide_woman_s_2018 = pd.Series(df_dict1)
suicide_man_s_2018.name  = '남자 자살_2018'
suicide_woman_s_2018.name = '여자 자살_2018'

# %%
df_dict = {}
df_dict1 = {}
df_list = ['종로구', '성북구', '중구', '용산구', '서대문구', '동대문구']
for i in df_list:
    df_dict[i] = suicide_man[suicide_man['sgg_nm'] == i].iloc[:, 5].sum()
    df_dict1[i] = suicide_woman[suicide_woman['sgg_nm'] == i].iloc[:, 5].sum()

# %%
suicide_man_s_2019 = pd.Series(df_dict)
suicide_woman_s_2019 = pd.Series(df_dict1)
suicide_man_s_2019.name = '남자 자살_2019'
suicide_woman_s_2019.name = '여자 자살_2019'

# %%
df_gicho = df_gicho.reset_index(drop = True)

# %%
df_gicho
# Out:
#           date   sido sgg_nm  age  num
# 0       201706  서울특별시    종로구    4    4
# 1       201706  서울특별시    종로구   45   26
# 2       201706  서울특별시    종로구   46   55
# 3       201706  서울특별시    종로구   47   37
# 4       201706  서울특별시    종로구   48   51
# ...        ...    ...    ...  ...  ...
# 125302  202105  서울특별시    강동구    0    8
# 125303  202105  서울특별시    강동구   40  110
# 125304  202105  서울특별시    강동구   41  119
# 125305  202105  서울특별시    강동구   42  125
# 125306  202105  서울특별시    강동구   43  120
#
# [125307 rows x 5 columns]

# %%
for i in range(len(df_gicho)):
    df_gicho['date'][i] = math.trunc((df_gicho['date'][i] *0.01 % 2000)) + 2000
# Out:
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_gicho['date']
# Out:
# 0         2017
# 1         2017
# 2         2017
# 3         2017
# 4         2017
#           ...
# 125302    2021
# 125303    2021
# 125304    2021
# 125305    2021
# 125306    2021
# Name: date, Length: 125307, dtype: int64

# %%
df_gicho[df_gicho['date'] == 2017]
# Out:
#        date   sido sgg_nm  age  num
# 0      2017  서울특별시    종로구    4    4
# 1      2017  서울특별시    종로구   45   26
# 2      2017  서울특별시    종로구   46   55
# 3      2017  서울특별시    종로구   47   37
# 4      2017  서울특별시    종로구   48   51
# ...     ...    ...    ...  ...  ...
# 20163  2017  서울특별시    강동구   39   52
# 20164  2017  서울특별시    강동구   40   56
# 20165  2017  서울특별시    강동구   41   54
# 20166  2017  서울특별시    강동구   42   68
# 20167  2017  서울특별시    강동구   43   73
#
# [20168 rows x 5 columns]

# %%
df_gicho_2017 = df_gicho[df_gicho['date'] == 2017]
df_gicho_2018 = df_gicho[df_gicho['date'] == 2018]
df_gicho_2019 = df_gicho[df_gicho['date'] == 2019]
df_gicho_2020 = df_gicho[df_gicho['date'] == 2020]
df_gicho_2021 = df_gicho[df_gicho['date'] == 2021]

# %%
df_dict = {}
df_dict1 = {}
df_dict2 = {}
df_dict3 = {}
df_dict4 = {}
df_list = ['종로구', '성북구', '중구', '용산구', '서대문구', '동대문구']
for i in df_list:
    
    df_dict[i] = df_gicho_2017[df_gicho_2017['sgg_nm'] == i].iloc[:,4].sum()
    df_dict1[i] = df_gicho_2018[df_gicho_2018['sgg_nm'] == i].iloc[:,4].sum()
    df_dict2[i] = df_gicho_2019[df_gicho_2019['sgg_nm'] == i].iloc[:,4].sum()
    df_dict3[i] = df_gicho_2020[df_gicho_2020['sgg_nm'] == i].iloc[:,4].sum()
    df_dict4[i] = df_gicho_2021[df_gicho_2021['sgg_nm'] == i].iloc[:,4].sum()

# %%
gicho_2017 = pd.Series(df_dict)
gicho_2018 = pd.Series(df_dict1)
gicho_2019 = pd.Series(df_dict2)
gicho_2020 = pd.Series(df_dict3)
gicho_2021 = pd.Series(df_dict4)
gicho_2017.name = '기초수급자 현황_2017'
gicho_2018.name = '기초수급자 현황_2018'
gicho_2019.name = '기초수급자 현황_2019'
gicho_2020.name = '기초수급자 현황_2020'
gicho_2021.name = '기초수급자 현황_2021'

# %%
df = pd.concat([df, fire_2019_s, fire_2020_s, one_woman_2017, one_man_2017, one_woman_2018, one_man_2018,
                one_woman_2019, one_man_2019, suicide_man_s_2017, suicide_woman_s_2017,
                suicide_man_s_2018, suicide_woman_s_2018, suicide_man_s_2019, suicide_woman_s_2019,
                gicho_2017, gicho_2018, gicho_2019, gicho_2020, gicho_2021], axis = 1)

# %%
df.to_csv('구별.csv')

# %%
df
# Out:
#       화재발생_2018  화재발생_2019  화재발생_2020  2017 1인가구_여자  2017 1인가구_남자  \
# 종로구         254        232        217         10247          9013
# 성북구         215        191        173         27285         22237
# 중구          275        213        185         48653         45059
# 용산구         211        238        192         16297         13023
# 서대문구        229        269        220         22180         16856
# 동대문구        203        195        152         22999         23324
#
#       2018 1인가구_여자  2018 1인가구_남자  2019 1인가구_여자  2019 1인가구_남자  남자 자살_2017  \
# 종로구          10766          9867         10766          9867          33
# 성북구          27921         22430         27921         22430          69
# 중구           50780         46690         50780         46690          20
# 용산구          16556         13300         16556         13300          36
# 서대문구         22734         17477         22734         17477          42
# ...
